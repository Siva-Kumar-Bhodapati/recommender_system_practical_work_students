# %% [markdown]
# http://surpriselib.com

# %% [markdown]
# # Load data

# %%
from surprise import Dataset

data = Dataset.load_builtin('ml-100k')

# %% [markdown]
# # Manual pipeline

# %% [markdown]
# ## Split data in train and test

# %%
from surprise.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
test
# Out:
# [('907', '143', 5.0),
#  ('371', '210', 4.0),
#  ('218', '42', 4.0),
#  ('829', '170', 4.0),
#  ('733', '277', 1.0),
#  ('363', '1512', 1.0),
#  ('193', '487', 5.0),
#  ('808', '313', 5.0),
#  ('557', '682', 2.0),
#  ('774', '196', 3.0),
#  ('638', '118', 3.0),
#  ('632', '81', 5.0),
#  ('417', '200', 4.0),
#  ('580', '471', 3.0),
#  ('640', '91', 4.0),
#  ('450', '328', 4.0),
#  ('596', '13', 2.0),
#  ('586', '467', 4.0),
#  ('653', '502', 2.0),
#  ('378', '517', 3.0),
#  ('405', '65', 1.0),
#  ('279', '399', 4.0),
#  ('327', '293', 3.0),
#  ('346', '276', 1.0),
#  ('59', '928', 4.0),
#  ('514', '22', 4.0),
#  ('807', '402', 5.0),
#  ('473', '327', 3.0),
#  ('342', '324', 1.0),
#  ('269', '136', 4.0),
#  ('654', '1', 4.0),
#  ('250', '28', 4.0),
#  ('282', '689', 2.0),
#  ('534', '619', 4.0),
#  ('194', '481', 3.0),
#  ('184', '118', 2.0),
#  ('291', '739', 3.0),
#  ('293', '31', 2.0),
#  ('943', '1028', 2.0),
#  ('65', '69', 3.0),
#  ('562', '135', 5.0),
#  ('466', '62', 3.0),
#  ('847', '317', 3.0),
#  ('650', '521', 3.0),
#  ('656', '326', 1.0),
#  ('366', '53', 5.0),
#  ('15', '280', 3.0),
#  ('474', '322', 4.0),
#  ('90', '905', 4.0),
#  ('503', '19', 5.0),
#  ('334', '1524', 4.0),
#  ('90', '632', 5.0),
#  ('406', '1118', 3.0),
#  ('899', '515', 3.0),
#  ('13', '339', 3.0),
#  ('430', '19', 5.0),
#  ('24', '729', 5.0),
#  ('634', '225', 3.0),
#  ('727', '89', 5.0),
#  ('429', '596', 3.0),
#  ('62', '127', 4.0),
#  ('771', '241', 1.0),
#  ('733', '762', 4.0),
#  ('139', '222', 3.0),
#  ('916', '721', 4.0),
#  ('402', '204', 5.0),
#  ('553', '136', 4.0),
#  ('62', '1073', 4.0),
#  ('521', '271', 3.0),
#  ('488', '358', 3.0),
#  ('7', '231', 3.0),
#  ('346', '727', 1.0),
#  ('423', '823', 3.0),
#  ('405', '575', 5.0),
#  ('385', '1158', 5.0),
#  ('630', '125', 3.0),
#  ('551', '125', 4.0),
#  ('727', '183', 3.0),
#  ('660', '810', 3.0),
#  ('552', '323', 2.0),
#  ('13', '604', 5.0),
#  ('642', '812', 4.0),
#  ('240', '269', 5.0),
#  ('321', '191', 3.0),
#  ('85', '921', 3.0),
#  ('671', '161', 5.0),
#  ('253', '97', 4.0),
#  ('605', '187', 5.0),
#  ('472', '625', 4.0),
#  ('56', '449', 5.0),
#  ('881', '141', 3.0),
#  ('391', '318', 4.0),
#  ('601', '387', 3.0),
#  ('497', '475', 4.0),
#  ('327', '921', 4.0),
#  ('200', '1033', 2.0),
#  ('605', '64', 5.0),
#  ('796', '879', 4.0),
#  ('214', '216', 4.0),
#  ('566', '161', 4.0),
#  ('653', '423', 2.0),
#  ('344', '216', 4.0),
#  ('151', '664', 5.0),
#  ('64', '751', 2.0),
#  ('554', '87', 4.0),
#  ('384', '327', 4.0),
#  ('798', '1032', 3.0),
#  ('622', '90', 4.0),
#  ('719', '735', 5.0),
#  ('424', '740', 5.0),
#  ('294', '358', 2.0),
#  ('21', '396', 2.0),
#  ('690', '197', 4.0),
#  ('360', '471', 4.0),
#  ('734', '603', 4.0),
#  ('521', '174', 4.0),
#  ('484', '300', 4.0),
#  ('128', '50', 4.0),
#  ('633', '921', 3.0),
#  ('854', '466', 3.0),
#  ('493', '751', 5.0),
#  ('504', '392', 5.0),
#  ('655', '318', 4.0),
#  ('650', '157', 3.0),
#  ('104', '273', 3.0),
#  ('872', '117', 4.0),
#  ('276', '1170', 4.0),
#  ('146', '258', 4.0),
#  ('222', '1066', 1.0),
#  ('380', '199', 3.0),
#  ('618', '195', 3.0),
#  ('358', '1266', 4.0),
#  ('871', '813', 3.0),
#  ('234', '174', 3.0),
#  ('912', '15', 4.0),
#  ('75', '237', 2.0),
#  ('713', '270', 2.0),
#  ('251', '33', 3.0),
#  ('275', '199', 4.0),
#  ('766', '91', 5.0),
#  ('22', '204', 5.0),
#  ('487', '591', 2.0),
#  ('827', '316', 3.0),
#  ('919', '22', 5.0),
#  ('637', '274', 5.0),
#  ('666', '856', 5.0),
#  ('349', '458', 4.0),
#  ('880', '1197', 3.0),
#  ('30', '892', 4.0),
#  ('716', '213', 5.0),
#  ('235', '70', 5.0),
#  ('291', '1042', 4.0),
#  ('655', '311', 3.0),
#  ('387', '642', 4.0),
#  ('109', '31', 4.0),
#  ('484', '69', 5.0),
#  ('393', '7', 4.0),
#  ('314', '53', 1.0),
#  ('845', '1394', 4.0),
#  ('532', '311', 2.0),
#  ('195', '558', 3.0),
#  ('89', '151', 5.0),
#  ('824', '243', 1.0),
#  ('632', '11', 4.0),
#  ('393', '412', 3.0),
#  ('887', '121', 5.0),
#  ('682', '412', 1.0),
#  ('406', '210', 5.0),
#  ('795', '552', 2.0),
#  ('774', '546', 1.0),
#  ('47', '304', 3.0),
#  ('514', '15', 4.0),
#  ('804', '175', 4.0),
#  ('804', '1056', 4.0),
#  ('21', '243', 2.0),
#  ('618', '778', 3.0),
#  ('151', '222', 5.0),
#  ('224', '583', 1.0),
#  ('283', '709', 5.0),
#  ('504', '185', 5.0),
#  ('553', '135', 4.0),
#  ('846', '203', 5.0),
#  ('773', '52', 3.0),
#  ('385', '384', 1.0),
#  ('346', '720', 2.0),
#  ('373', '366', 4.0),
#  ('881', '474', 3.0),
#  ('537', '845', 2.0),
#  ('474', '50', 5.0),
#  ('293', '77', 2.0),
#  ('542', '435', 4.0),
#  ('262', '111', 4.0),
#  ('109', '1210', 3.0),
#  ('181', '1164', 3.0),
#  ('847', '96', 4.0),
#  ('625', '640', 3.0),
#  ('246', '178', 5.0),
#  ('425', '24', 2.0),
#  ('749', '712', 3.0),
#  ('586', '227', 2.0),
#  ('410', '754', 3.0),
#  ('332', '9', 4.0),
#  ('185', '47', 4.0),
#  ('582', '826', 3.0),
#  ('130', '217', 3.0),
#  ('537', '426', 1.0),
#  ('295', '380', 4.0),
#  ('756', '151', 4.0),
#  ('749', '826', 3.0),
#  ('405', '657', 1.0),
#  ('622', '1407', 1.0),
#  ('425', '825', 2.0),
#  ('372', '56', 4.0),
#  ('338', '1124', 4.0),
#  ('795', '568', 3.0),
#  ('99', '694', 1.0),
#  ('717', '980', 4.0),
#  ('470', '952', 3.0),
#  ('268', '153', 5.0),
#  ('425', '853', 4.0),
#  ('457', '566', 4.0),
#  ('73', '433', 4.0),
#  ('397', '665', 3.0),
#  ('466', '357', 4.0),
#  ('389', '1114', 2.0),
#  ('328', '903', 3.0),
#  ('378', '742', 4.0),
#  ('65', '211', 4.0),
#  ('333', '98', 4.0),
#  ('886', '240', 3.0),
#  ('897', '673', 5.0),
#  ('224', '720', 4.0),
#  ('934', '526', 2.0),
#  ('181', '931', 1.0),
#  ('839', '50', 5.0),
#  ('782', '322', 4.0),
#  ('181', '263', 1.0),
#  ('880', '40', 2.0),
#  ('505', '588', 5.0),
#  ('207', '433', 3.0),
#  ('500', '619', 3.0),
#  ('181', '360', 1.0),
#  ('922', '62', 3.0),
#  ('815', '735', 5.0),
#  ('782', '937', 1.0),
#  ('894', '638', 3.0),
#  ('551', '698', 4.0),
#  ('246', '1101', 5.0),
#  ('131', '275', 2.0),
#  ('606', '248', 5.0),
#  ('854', '191', 4.0),
#  ('889', '3', 4.0),
#  ('547', '294', 1.0),
#  ('211', '303', 3.0),
#  ('883', '707', 3.0),
#  ('823', '228', 3.0),
#  ('889', '173', 5.0),
#  ('293', '117', 3.0),
#  ('723', '164', 4.0),
#  ('313', '720', 2.0),
#  ('87', '8', 5.0),
#  ('305', '215', 2.0),
#  ('588', '1411', 1.0),
#  ('83', '50', 3.0),
#  ('81', '432', 2.0),
#  ('372', '77', 5.0),
#  ('409', '1512', 5.0),
#  ('194', '125', 2.0),
#  ('745', '510', 3.0),
#  ('749', '191', 4.0),
#  ('821', '117', 3.0),
#  ('552', '926', 2.0),
#  ('541', '659', 5.0),
#  ('682', '735', 4.0),
#  ('424', '127', 4.0),
#  ('854', '264', 1.0),
#  ('389', '492', 5.0),
#  ('354', '208', 4.0),
#  ('527', '127', 5.0),
#  ('378', '302', 5.0),
#  ('903', '1009', 4.0),
#  ('484', '15', 5.0),
#  ('62', '7', 4.0),
#  ('387', '692', 1.0),
#  ('641', '270', 3.0),
#  ('164', '9', 4.0),
#  ('608', '204', 4.0),
#  ('459', '472', 5.0),
#  ('566', '122', 2.0),
#  ('398', '4', 2.0),
#  ('407', '274', 3.0),
#  ('144', '273', 4.0),
#  ('523', '582', 4.0),
#  ('613', '607', 4.0),
#  ('416', '690', 5.0),
#  ('610', '317', 3.0),
#  ('758', '91', 4.0),
#  ('308', '58', 3.0),
#  ('334', '620', 2.0),
#  ('833', '506', 2.0),
#  ('70', '231', 3.0),
#  ('399', '1035', 3.0),
#  ('13', '64', 5.0),
#  ('534', '93', 1.0),
#  ('843', '708', 2.0),
#  ('639', '714', 2.0),
#  ('663', '321', 5.0),
#  ('189', '1402', 4.0),
#  ('457', '172', 5.0),
#  ('640', '580', 5.0),
#  ('94', '356', 4.0),
#  ('504', '187', 3.0),
#  ('436', '288', 4.0),
#  ('541', '1030', 3.0),
#  ('551', '168', 5.0),
#  ('703', '15', 5.0),
#  ('521', '228', 4.0),
#  ('510', '325', 1.0),
#  ('463', '689', 2.0),
#  ('312', '499', 4.0),
#  ('533', '357', 3.0),
#  ('393', '794', 4.0),
#  ('642', '748', 5.0),
#  ('851', '1291', 2.0),
#  ('128', '507', 4.0),
#  ('568', '653', 4.0),
#  ('325', '1', 2.0),
#  ('345', '161', 3.0),
#  ('741', '280', 3.0),
#  ('545', '222', 4.0),
#  ('778', '144', 4.0),
#  ('874', '137', 4.0),
#  ('897', '1254', 2.0),
#  ('385', '1143', 4.0),
#  ('487', '43', 3.0),
#  ('425', '269', 4.0),
#  ('758', '412', 5.0),
#  ('313', '191', 5.0),
#  ('11', '414', 3.0),
#  ('225', '1443', 4.0),
#  ('849', '676', 5.0),
#  ('616', '339', 3.0),
#  ('109', '131', 1.0),
#  ('548', '164', 5.0),
#  ('455', '1034', 2.0),
#  ('289', '849', 4.0),
#  ('896', '148', 2.0),
#  ('38', '294', 5.0),
#  ('194', '385', 2.0),
#  ('385', '235', 5.0),
#  ('553', '131', 5.0),
#  ('896', '184', 3.0),
#  ('940', '315', 4.0),
#  ('178', '144', 4.0),
#  ('482', '311', 4.0),
#  ('327', '663', 4.0),
#  ('601', '173', 5.0),
#  ('345', '150', 5.0),
#  ('761', '1014', 1.0),
#  ('790', '1119', 4.0),
#  ('489', '989', 3.0),
#  ('38', '318', 3.0),
#  ('279', '1496', 3.0),
#  ('923', '591', 5.0),
#  ('323', '215', 5.0),
#  ('376', '181', 4.0),
#  ('927', '541', 5.0),
#  ('416', '1286', 5.0),
#  ('268', '655', 4.0),
#  ('64', '196', 4.0),
#  ('271', '427', 5.0),
#  ('122', '511', 5.0),
#  ('167', '404', 3.0),
#  ('580', '281', 2.0),
#  ('95', '510', 4.0),
#  ('615', '237', 4.0),
#  ('663', '25', 4.0),
#  ('883', '517', 4.0),
#  ('189', '30', 4.0),
#  ('735', '333', 4.0),
#  ('711', '272', 5.0),
#  ('874', '124', 4.0),
#  ('796', '525', 4.0),
#  ('668', '596', 3.0),
#  ('533', '9', 4.0),
#  ('851', '248', 4.0),
#  ('360', '14', 5.0),
#  ('62', '181', 4.0),
#  ('579', '514', 3.0),
#  ('158', '745', 4.0),
#  ('119', '1052', 4.0),
#  ('275', '162', 3.0),
#  ('503', '277', 4.0),
#  ('710', '496', 4.0),
#  ('660', '550', 2.0),
#  ('42', '151', 4.0),
#  ('479', '147', 3.0),
#  ('574', '887', 4.0),
#  ('13', '655', 5.0),
#  ('593', '220', 3.0),
#  ('524', '526', 3.0),
#  ('244', '721', 5.0),
#  ('774', '567', 1.0),
#  ('848', '132', 5.0),
#  ('851', '435', 4.0),
#  ('198', '58', 3.0),
#  ('286', '210', 5.0),
#  ('608', '753', 5.0),
#  ('303', '379', 4.0),
#  ('271', '221', 3.0),
#  ('492', '650', 2.0),
#  ('782', '1278', 4.0),
#  ('864', '609', 3.0),
#  ('763', '357', 4.0),
#  ('894', '45', 4.0),
#  ('272', '201', 3.0),
#  ('264', '275', 5.0),
#  ('286', '278', 5.0),
#  ('190', '508', 3.0),
#  ('80', '194', 3.0),
#  ('916', '222', 3.0),
#  ('532', '495', 4.0),
#  ('929', '136', 3.0),
#  ('178', '731', 4.0),
#  ('327', '537', 4.0),
#  ('591', '172', 3.0),
#  ('679', '268', 4.0),
#  ('795', '429', 3.0),
#  ('234', '321', 2.0),
#  ('698', '275', 4.0),
#  ('385', '503', 3.0),
#  ('268', '746', 3.0),
#  ('682', '774', 4.0),
#  ('244', '287', 3.0),
#  ('387', '175', 5.0),
#  ('707', '194', 4.0),
#  ('216', '189', 3.0),
#  ('524', '523', 4.0),
#  ('486', '288', 4.0),
#  ('395', '252', 3.0),
#  ('620', '78', 4.0),
#  ('892', '64', 4.0),
#  ('345', '241', 4.0),
#  ('593', '597', 2.0),
#  ('895', '1', 4.0),
#  ('18', '237', 3.0),
#  ('60', '151', 5.0),
#  ('417', '39', 3.0),
#  ('823', '721', 4.0),
#  ('286', '231', 3.0),
#  ('389', '47', 4.0),
#  ('298', '1142', 4.0),
#  ('216', '200', 5.0),
#  ('236', '204', 3.0),
#  ('393', '808', 4.0),
#  ('704', '354', 4.0),
#  ('416', '1189', 5.0),
#  ('349', '696', 3.0),
#  ('90', '174', 5.0),
#  ('828', '1466', 4.0),
#  ('286', '1239', 3.0),
#  ('279', '275', 3.0),
#  ('451', '322', 4.0),
#  ('405', '959', 1.0),
#  ('718', '815', 4.0),
#  ('321', '116', 3.0),
#  ('334', '134', 5.0),
#  ('522', '12', 5.0),
#  ('889', '469', 4.0),
#  ('930', '282', 4.0),
#  ('215', '210', 4.0),
#  ('716', '603', 5.0),
#  ('326', '568', 4.0),
#  ('919', '287', 4.0),
#  ('344', '25', 4.0),
#  ('862', '650', 4.0),
#  ('153', '357', 5.0),
#  ('627', '521', 2.0),
#  ('901', '1120', 4.0),
#  ('868', '470', 1.0),
#  ('267', '47', 5.0),
#  ('361', '166', 4.0),
#  ('417', '217', 4.0),
#  ('459', '546', 1.0),
#  ('152', '22', 5.0),
#  ('625', '188', 4.0),
#  ('401', '294', 1.0),
#  ('160', '79', 4.0),
#  ('910', '100', 4.0),
#  ('179', '905', 4.0),
#  ('379', '502', 5.0),
#  ('796', '371', 5.0),
#  ('653', '163', 4.0),
#  ('746', '208', 4.0),
#  ('45', '284', 4.0),
#  ('766', '526', 2.0),
#  ('303', '578', 2.0),
#  ('898', '309', 5.0),
#  ('593', '866', 5.0),
#  ('643', '144', 4.0),
#  ('270', '747', 5.0),
#  ('474', '23', 4.0),
#  ('121', '237', 5.0),
#  ('479', '474', 5.0),
#  ('532', '771', 3.0),
#  ('121', '313', 5.0),
#  ('912', '268', 2.0),
#  ('764', '673', 4.0),
#  ('387', '1537', 4.0),
#  ('34', '288', 2.0),
#  ('344', '118', 3.0),
#  ('482', '127', 4.0),
#  ('456', '697', 4.0),
#  ('260', '748', 4.0),
#  ('305', '135', 3.0),
#  ('457', '114', 5.0),
#  ('339', '161', 3.0),
#  ('18', '702', 3.0),
#  ('918', '190', 5.0),
#  ('614', '14', 3.0),
#  ('470', '7', 3.0),
#  ('93', '934', 3.0),
#  ('407', '151', 4.0),
#  ('466', '173', 3.0),
#  ('279', '824', 4.0),
#  ('401', '185', 4.0),
#  ('779', '118', 5.0),
#  ('184', '629', 3.0),
#  ('102', '118', 3.0),
#  ('313', '636', 4.0),
#  ('232', '166', 4.0),
#  ('370', '427', 5.0),
#  ('320', '22', 5.0),
#  ('299', '1021', 3.0),
#  ('786', '230', 4.0),
#  ('867', '222', 4.0),
#  ('472', '386', 5.0),
#  ('826', '313', 5.0),
#  ('893', '412', 3.0),
#  ('757', '570', 3.0),
#  ('709', '431', 5.0),
#  ('705', '423', 2.0),
#  ('425', '187', 3.0),
#  ('268', '325', 3.0),
#  ('215', '474', 4.0),
#  ('9', '340', 4.0),
#  ('770', '742', 4.0),
#  ('762', '749', 1.0),
#  ('437', '248', 2.0),
#  ('13', '88', 4.0),
#  ('373', '196', 5.0),
#  ('429', '45', 3.0),
#  ('560', '7', 3.0),
#  ('123', '127', 5.0),
#  ('405', '226', 2.0),
#  ('756', '742', 3.0),
#  ('276', '665', 3.0),
#  ('63', '25', 4.0),
#  ('884', '198', 5.0),
#  ('653', '50', 5.0),
#  ('677', '288', 5.0),
#  ('561', '513', 3.0),
#  ('213', '294', 3.0),
#  ('188', '288', 4.0),
#  ('634', '866', 3.0),
#  ('896', '655', 4.0),
#  ('653', '223', 3.0),
#  ('817', '327', 4.0),
#  ('585', '855', 3.0),
#  ('782', '908', 3.0),
#  ('758', '234', 4.0),
#  ('295', '1459', 5.0),
#  ('655', '262', 5.0),
#  ('709', '227', 2.0),
#  ('64', '64', 4.0),
#  ('201', '289', 2.0),
#  ('291', '79', 5.0),
#  ('452', '94', 1.0),
#  ('474', '651', 5.0),
#  ('234', '1172', 3.0),
#  ('458', '275', 5.0),
#  ('927', '552', 4.0),
#  ('321', '1050', 3.0),
#  ('113', '303', 5.0),
#  ('706', '323', 4.0),
#  ('92', '527', 3.0),
#  ('83', '233', 4.0),
#  ('747', '419', 5.0),
#  ('234', '172', 3.0),
#  ('868', '568', 1.0),
#  ('372', '443', 4.0),
#  ('95', '716', 3.0),
#  ('97', '1', 4.0),
#  ('758', '1052', 5.0),
#  ('897', '443', 5.0),
#  ('320', '1011', 3.0),
#  ('279', '169', 5.0),
#  ('291', '1012', 4.0),
#  ('49', '10', 3.0),
#  ('738', '89', 5.0),
#  ('711', '403', 4.0),
#  ('524', '508', 5.0),
#  ('521', '651', 3.0),
#  ('633', '581', 3.0),
#  ('574', '213', 4.0),
#  ('878', '269', 4.0),
#  ('727', '38', 1.0),
#  ('610', '318', 5.0),
#  ('592', '461', 4.0),
#  ('562', '684', 4.0),
#  ('407', '8', 5.0),
#  ('938', '756', 3.0),
#  ('671', '327', 1.0),
#  ('731', '487', 4.0),
#  ('933', '227', 1.0),
#  ('805', '475', 5.0),
#  ('592', '345', 4.0),
#  ('389', '503', 3.0),
#  ('487', '92', 4.0),
#  ('932', '235', 2.0),
#  ('580', '1028', 3.0),
#  ('761', '1277', 1.0),
#  ('386', '181', 3.0),
#  ('145', '155', 2.0),
#  ('181', '148', 2.0),
#  ('618', '68', 3.0),
#  ('18', '474', 4.0),
#  ('672', '1190', 2.0),
#  ('399', '622', 4.0),
#  ('446', '302', 4.0),
#  ('848', '511', 4.0),
#  ('144', '262', 3.0),
#  ('660', '99', 2.0),
#  ('892', '1091', 2.0),
#  ('303', '164', 4.0),
#  ('417', '1210', 2.0),
#  ('421', '234', 5.0),
#  ('524', '382', 3.0),
#  ('290', '1091', 2.0),
#  ('18', '8', 5.0),
#  ('311', '785', 3.0),
#  ('727', '202', 4.0),
#  ('804', '615', 5.0),
#  ('579', '186', 3.0),
#  ('303', '1044', 3.0),
#  ('161', '204', 2.0),
#  ('320', '24', 3.0),
#  ('562', '806', 1.0),
#  ('10', '558', 4.0),
#  ('881', '49', 5.0),
#  ('738', '174', 5.0),
#  ('786', '684', 4.0),
#  ('23', '283', 4.0),
#  ('545', '393', 4.0),
#  ('608', '690', 4.0),
#  ('608', '333', 4.0),
#  ('194', '79', 3.0),
#  ('339', '53', 4.0),
#  ('162', '179', 3.0),
#  ('650', '117', 4.0),
#  ('442', '226', 3.0),
#  ('867', '28', 5.0),
#  ('435', '125', 3.0),
#  ('334', '19', 4.0),
#  ('804', '210', 5.0),
#  ('849', '421', 5.0),
#  ('543', '9', 4.0),
#  ('181', '620', 2.0),
#  ('889', '11', 5.0),
#  ('313', '231', 2.0),
#  ('801', '752', 4.0),
#  ('59', '433', 5.0),
#  ('563', '172', 5.0),
#  ('712', '462', 3.0),
#  ('159', '126', 5.0),
#  ('508', '70', 4.0),
#  ('653', '492', 4.0),
#  ('407', '588', 4.0),
#  ('293', '240', 2.0),
#  ('210', '243', 2.0),
#  ('765', '507', 5.0),
#  ('102', '1240', 2.0),
#  ('655', '286', 3.0),
#  ('618', '276', 3.0),
#  ('916', '474', 4.0),
#  ('943', '581', 4.0),
#  ('930', '100', 3.0),
#  ('271', '509', 4.0),
#  ('301', '771', 2.0),
#  ('7', '652', 3.0),
#  ('561', '642', 3.0),
#  ('84', '322', 3.0),
#  ('116', '270', 3.0),
#  ('334', '164', 3.0),
#  ('764', '77', 4.0),
#  ('737', '173', 4.0),
#  ('907', '173', 4.0),
#  ('805', '1033', 3.0),
#  ('141', '237', 4.0),
#  ('145', '1288', 4.0),
#  ('901', '560', 3.0),
#  ('588', '172', 5.0),
#  ('62', '288', 2.0),
#  ('62', '228', 3.0),
#  ('444', '751', 4.0),
#  ('450', '82', 3.0),
#  ('389', '386', 3.0),
#  ('567', '673', 3.0),
#  ('670', '232', 3.0),
#  ('756', '1074', 4.0),
#  ('387', '1011', 3.0),
#  ('447', '629', 3.0),
#  ('704', '519', 3.0),
#  ('653', '517', 1.0),
#  ('198', '381', 3.0),
#  ('899', '423', 4.0),
#  ('927', '257', 5.0),
#  ('91', '326', 3.0),
#  ('244', '156', 4.0),
#  ('943', '56', 5.0),
#  ('880', '186', 4.0),
#  ('843', '392', 2.0),
#  ('339', '97', 4.0),
#  ('199', '14', 4.0),
#  ('447', '926', 3.0),
#  ('629', '234', 4.0),
#  ('694', '528', 3.0),
#  ('314', '15', 5.0),
#  ('524', '116', 4.0),
#  ('432', '295', 3.0),
#  ('655', '340', 3.0),
#  ('334', '311', 4.0),
#  ('747', '408', 5.0),
#  ('506', '660', 3.0),
#  ('244', '710', 3.0),
#  ('276', '157', 5.0),
#  ('327', '88', 2.0),
#  ('702', '258', 5.0),
#  ('309', '324', 3.0),
#  ('37', '62', 5.0),
#  ('148', '172', 5.0),
#  ('417', '545', 1.0),
#  ('650', '301', 2.0),
#  ('94', '97', 4.0),
#  ('332', '12', 5.0),
#  ('536', '209', 2.0),
#  ('698', '220', 3.0),
#  ('151', '100', 3.0),
#  ('70', '496', 4.0),
#  ('268', '21', 3.0),
#  ('14', '70', 1.0),
#  ('690', '239', 2.0),
#  ('458', '589', 4.0),
#  ('7', '523', 4.0),
#  ('378', '793', 3.0),
#  ('297', '27', 1.0),
#  ('59', '208', 5.0),
#  ('18', '116', 5.0),
#  ('495', '1118', 5.0),
#  ('396', '245', 3.0),
#  ('837', '277', 2.0),
#  ('297', '102', 1.0),
#  ('846', '55', 5.0),
#  ('368', '441', 3.0),
#  ('643', '428', 4.0),
#  ('62', '245', 2.0),
#  ('383', '180', 5.0),
#  ('804', '1291', 3.0),
#  ('116', '300', 3.0),
#  ('632', '176', 3.0),
#  ('76', '264', 3.0),
#  ('704', '432', 5.0),
#  ('773', '268', 4.0),
#  ('413', '222', 4.0),
#  ('374', '69', 5.0),
#  ('201', '210', 2.0),
#  ('8', '172', 5.0),
#  ('327', '1012', 2.0),
#  ('326', '44', 1.0),
#  ('496', '156', 3.0),
#  ('296', '111', 3.0),
#  ('80', '260', 1.0),
#  ('682', '809', 2.0),
#  ('700', '98', 3.0),
#  ('293', '79', 3.0),
#  ('130', '761', 3.0),
#  ('524', '490', 3.0),
#  ('699', '762', 3.0),
#  ('730', '685', 2.0),
#  ('833', '144', 4.0),
#  ('777', '286', 2.0),
#  ('311', '498', 4.0),
#  ('314', '158', 3.0),
#  ('375', '302', 5.0),
#  ('60', '498', 5.0),
#  ('579', '4', 2.0),
#  ('537', '22', 2.0),
#  ('377', '200', 5.0),
#  ('828', '921', 4.0),
#  ('497', '139', 3.0),
#  ('591', '516', 3.0),
#  ('908', '194', 3.0),
#  ('198', '153', 4.0),
#  ('290', '683', 2.0),
#  ('815', '87', 5.0),
#  ('59', '237', 3.0),
#  ('422', '590', 2.0),
#  ('308', '71', 4.0),
#  ('394', '98', 5.0),
#  ('62', '98', 4.0),
#  ('829', '410', 3.0),
#  ('544', '343', 2.0),
#  ('617', '868', 4.0),
#  ('56', '71', 4.0),
#  ('429', '514', 3.0),
#  ('339', '1110', 4.0),
#  ('617', '669', 1.0),
#  ('549', '1047', 3.0),
#  ('647', '255', 4.0),
#  ('222', '1206', 2.0),
#  ('363', '739', 3.0),
#  ('291', '184', 4.0),
#  ('301', '271', 4.0),
#  ('118', '188', 5.0),
#  ('757', '1188', 3.0),
#  ('891', '280', 3.0),
#  ('565', '165', 4.0),
#  ('308', '81', 5.0),
#  ('530', '470', 3.0),
#  ('243', '93', 2.0),
#  ('59', '371', 4.0),
#  ('664', '1098', 3.0),
#  ('26', '760', 1.0),
#  ('830', '211', 4.0),
#  ('900', '9', 2.0),
#  ('864', '2', 4.0),
#  ('597', '242', 4.0),
#  ('22', '792', 4.0),
#  ('165', '270', 4.0),
#  ('483', '462', 3.0),
#  ('593', '144', 4.0),
#  ('299', '461', 3.0),
#  ('280', '237', 3.0),
#  ('327', '176', 4.0),
#  ('200', '196', 4.0),
#  ('264', '672', 3.0),
#  ('405', '48', 1.0),
#  ('429', '961', 3.0),
#  ('215', '164', 3.0),
#  ('569', '340', 4.0),
#  ('621', '804', 4.0),
#  ('188', '22', 5.0),
#  ('360', '144', 2.0),
#  ('293', '132', 4.0),
#  ('399', '343', 2.0),
#  ('456', '86', 2.0),
#  ('407', '157', 2.0),
#  ('707', '100', 5.0),
#  ('328', '750', 4.0),
#  ('488', '173', 4.0),
#  ('868', '229', 3.0),
#  ('151', '531', 3.0),
#  ('848', '523', 5.0),
#  ('454', '95', 2.0),
#  ('368', '7', 4.0),
#  ('807', '526', 5.0),
#  ('708', '15', 3.0),
#  ('845', '904', 3.0),
#  ('658', '471', 4.0),
#  ('328', '194', 3.0),
#  ('663', '473', 3.0),
#  ('537', '523', 3.0),
#  ('323', '1012', 4.0),
#  ('92', '834', 1.0),
#  ('161', '582', 1.0),
#  ('198', '568', 3.0),
#  ('650', '429', 4.0),
#  ('776', '708', 5.0),
#  ('617', '320', 5.0),
#  ('843', '121', 3.0),
#  ('196', '173', 2.0),
#  ('37', '273', 3.0),
#  ('402', '410', 1.0),
#  ('487', '1', 5.0),
#  ('133', '750', 4.0),
#  ('123', '23', 4.0),
#  ('788', '1248', 3.0),
#  ('606', '1280', 2.0),
#  ('151', '181', 5.0),
#  ('305', '338', 3.0),
#  ('889', '297', 3.0),
#  ('253', '294', 4.0),
#  ('553', '191', 4.0),
#  ('409', '1541', 4.0),
#  ('285', '150', 5.0),
#  ('77', '268', 5.0),
#  ('455', '1137', 3.0),
#  ('483', '313', 2.0),
#  ('84', '15', 4.0),
#  ('709', '739', 3.0),
#  ('579', '7', 3.0),
#  ('327', '709', 4.0),
#  ('805', '405', 3.0),
#  ('786', '86', 4.0),
#  ('334', '301', 2.0),
#  ('388', '773', 3.0),
#  ('222', '1419', 1.0),
#  ('151', '433', 3.0),
#  ('556', '187', 5.0),
#  ('850', '490', 5.0),
#  ('291', '41', 4.0),
#  ('846', '739', 4.0),
#  ('332', '97', 5.0),
#  ('388', '307', 4.0),
#  ('776', '134', 4.0),
#  ('642', '955', 3.0),
#  ('622', '402', 3.0),
#  ('890', '436', 3.0),
#  ('269', '640', 5.0),
#  ('6', '32', 4.0),
#  ('313', '155', 2.0),
#  ('417', '452', 2.0),
#  ('685', '299', 2.0),
#  ('469', '64', 5.0),
#  ('806', '455', 3.0),
#  ('370', '64', 4.0),
#  ('313', '582', 2.0),
#  ('303', '873', 3.0),
#  ('363', '39', 4.0),
#  ('882', '756', 3.0),
#  ('466', '909', 5.0),
#  ('59', '25', 4.0),
#  ('186', '588', 4.0),
#  ('735', '288', 4.0),
#  ('52', '288', 3.0),
#  ('624', '255', 3.0),
#  ('868', '378', 2.0),
#  ('847', '367', 3.0),
#  ('675', '347', 4.0),
#  ('210', '97', 5.0),
#  ('929', '654', 3.0),
#  ('631', '307', 4.0),
#  ('72', '382', 4.0),
#  ('276', '77', 3.0),
#  ('459', '286', 4.0),
#  ('727', '421', 5.0),
#  ('75', '137', 4.0),
#  ('486', '327', 3.0),
#  ('882', '432', 5.0),
#  ('919', '1284', 3.0),
#  ('149', '310', 2.0),
#  ('5', '454', 1.0),
#  ('548', '466', 5.0),
#  ('546', '977', 5.0),
#  ('87', '196', 5.0),
#  ('847', '1', 3.0),
#  ('579', '88', 4.0),
#  ('345', '956', 4.0),
#  ('327', '715', 4.0),
#  ('234', '1221', 4.0),
#  ('854', '479', 4.0),
#  ('807', '566', 4.0),
#  ('396', '472', 5.0),
#  ('719', '79', 4.0),
#  ('312', '740', 4.0),
#  ('436', '785', 2.0),
#  ('592', '881', 1.0),
#  ('624', '886', 4.0),
#  ('916', '2', 3.0),
#  ('95', '71', 5.0),
#  ('262', '567', 1.0),
#  ('606', '168', 5.0),
#  ('398', '235', 2.0),
#  ('321', '215', 3.0),
#  ('686', '2', 3.0),
#  ('619', '879', 4.0),
#  ('932', '659', 5.0),
#  ('308', '275', 4.0),
#  ('782', '1241', 2.0),
#  ('351', '751', 4.0),
#  ('269', '661', 4.0),
#  ('93', '118', 3.0),
#  ('425', '823', 3.0),
#  ('524', '310', 4.0),
#  ('618', '371', 3.0),
#  ('268', '182', 4.0),
#  ('324', '538', 4.0),
#  ('899', '740', 5.0),
#  ('87', '80', 4.0),
#  ('825', '925', 4.0),
#  ('378', '272', 4.0),
#  ('774', '135', 3.0),
#  ('930', '238', 4.0),
#  ('704', '604', 5.0),
#  ('854', '509', 4.0),
#  ('704', '185', 4.0),
#  ('497', '1407', 3.0),
#  ('429', '166', 5.0),
#  ('255', '597', 4.0),
#  ('406', '136', 4.0),
#  ...]

# %%
train.n_users, train.n_items
# Out:
# (943, 1651)

# %% [markdown]
# ## Train model

# %% [markdown]
# - Use 2 models : user & item based
# https://surprise.readthedocs.io/en/stable/knn_inspired.html

# %%
from surprise import SVD

model = SVD()

# %%
model.fit(train)

# %% [markdown]
# ## Make predictions

# %%
predictions = model.test(test)
predictions
# Out:
# [Prediction(uid='907', iid='143', r_ui=5.0, est=4.8517497552112205, details={'was_impossible': False}),
#  Prediction(uid='371', iid='210', r_ui=4.0, est=4.2336039302898225, details={'was_impossible': False}),
#  Prediction(uid='218', iid='42', r_ui=4.0, est=3.5923614405339315, details={'was_impossible': False}),
#  Prediction(uid='829', iid='170', r_ui=4.0, est=4.008180210929193, details={'was_impossible': False}),
#  Prediction(uid='733', iid='277', r_ui=1.0, est=2.908722176520155, details={'was_impossible': False}),
#  Prediction(uid='363', iid='1512', r_ui=1.0, est=3.357134730170079, details={'was_impossible': False}),
#  Prediction(uid='193', iid='487', r_ui=5.0, est=3.5778387469577577, details={'was_impossible': False}),
#  Prediction(uid='808', iid='313', r_ui=5.0, est=4.357332887802932, details={'was_impossible': False}),
#  Prediction(uid='557', iid='682', r_ui=2.0, est=3.3001113935343422, details={'was_impossible': False}),
#  Prediction(uid='774', iid='196', r_ui=3.0, est=2.6598681496173238, details={'was_impossible': False}),
#  Prediction(uid='638', iid='118', r_ui=3.0, est=2.9996861935331602, details={'was_impossible': False}),
#  Prediction(uid='632', iid='81', r_ui=5.0, est=3.6570628044261944, details={'was_impossible': False}),
#  Prediction(uid='417', iid='200', r_ui=4.0, est=3.3980322805872794, details={'was_impossible': False}),
#  Prediction(uid='580', iid='471', r_ui=3.0, est=3.9099961042724276, details={'was_impossible': False}),
#  Prediction(uid='640', iid='91', r_ui=4.0, est=4.037008622497519, details={'was_impossible': False}),
#  Prediction(uid='450', iid='328', r_ui=4.0, est=4.376433936602185, details={'was_impossible': False}),
#  Prediction(uid='596', iid='13', r_ui=2.0, est=3.3294654986683136, details={'was_impossible': False}),
#  Prediction(uid='586', iid='467', r_ui=4.0, est=3.3297807187760267, details={'was_impossible': False}),
#  Prediction(uid='653', iid='502', r_ui=2.0, est=2.940007843843206, details={'was_impossible': False}),
#  Prediction(uid='378', iid='517', r_ui=3.0, est=3.9273126842446717, details={'was_impossible': False}),
#  Prediction(uid='405', iid='65', r_ui=1.0, est=1.7974300001645231, details={'was_impossible': False}),
#  Prediction(uid='279', iid='399', r_ui=4.0, est=3.418241049831886, details={'was_impossible': False}),
#  Prediction(uid='327', iid='293', r_ui=3.0, est=3.455086502024894, details={'was_impossible': False}),
#  Prediction(uid='346', iid='276', r_ui=1.0, est=2.9311103719817275, details={'was_impossible': False}),
#  Prediction(uid='59', iid='928', r_ui=4.0, est=3.345050568199122, details={'was_impossible': False}),
#  Prediction(uid='514', iid='22', r_ui=4.0, est=4.400586309161437, details={'was_impossible': False}),
#  Prediction(uid='807', iid='402', r_ui=5.0, est=3.829549619002629, details={'was_impossible': False}),
#  Prediction(uid='473', iid='327', r_ui=3.0, est=3.8236930599324745, details={'was_impossible': False}),
#  Prediction(uid='342', iid='324', r_ui=1.0, est=2.9776810588506017, details={'was_impossible': False}),
#  Prediction(uid='269', iid='136', r_ui=4.0, est=3.7991866541607218, details={'was_impossible': False}),
#  Prediction(uid='654', iid='1', r_ui=4.0, est=3.580133130809294, details={'was_impossible': False}),
#  Prediction(uid='250', iid='28', r_ui=4.0, est=3.911686200741194, details={'was_impossible': False}),
#  Prediction(uid='282', iid='689', r_ui=2.0, est=3.2517981367193265, details={'was_impossible': False}),
#  Prediction(uid='534', iid='619', r_ui=4.0, est=4.115042312442314, details={'was_impossible': False}),
#  Prediction(uid='194', iid='481', r_ui=3.0, est=3.3598994154822788, details={'was_impossible': False}),
#  Prediction(uid='184', iid='118', r_ui=2.0, est=2.8810286602511046, details={'was_impossible': False}),
#  Prediction(uid='291', iid='739', r_ui=3.0, est=3.6259492139672878, details={'was_impossible': False}),
#  Prediction(uid='293', iid='31', r_ui=2.0, est=3.1342769540746755, details={'was_impossible': False}),
#  Prediction(uid='943', iid='1028', r_ui=2.0, est=2.9528472139136843, details={'was_impossible': False}),
#  Prediction(uid='65', iid='69', r_ui=3.0, est=3.870587268933122, details={'was_impossible': False}),
#  Prediction(uid='562', iid='135', r_ui=5.0, est=3.774907817871309, details={'was_impossible': False}),
#  Prediction(uid='466', iid='62', r_ui=3.0, est=3.276588859161815, details={'was_impossible': False}),
#  Prediction(uid='847', iid='317', r_ui=3.0, est=3.5199135398188623, details={'was_impossible': False}),
#  Prediction(uid='650', iid='521', r_ui=3.0, est=3.35692007271951, details={'was_impossible': False}),
#  Prediction(uid='656', iid='326', r_ui=1.0, est=2.6176402863759263, details={'was_impossible': False}),
#  Prediction(uid='366', iid='53', r_ui=5.0, est=3.631684788618358, details={'was_impossible': False}),
#  Prediction(uid='15', iid='280', r_ui=3.0, est=2.6845894299128363, details={'was_impossible': False}),
#  Prediction(uid='474', iid='322', r_ui=4.0, est=3.2234325099847863, details={'was_impossible': False}),
#  Prediction(uid='90', iid='905', r_ui=4.0, est=3.8301365646938526, details={'was_impossible': False}),
#  Prediction(uid='503', iid='19', r_ui=5.0, est=4.492274909508129, details={'was_impossible': False}),
#  Prediction(uid='334', iid='1524', r_ui=4.0, est=3.7039094836126765, details={'was_impossible': False}),
#  Prediction(uid='90', iid='632', r_ui=5.0, est=4.318537943758976, details={'was_impossible': False}),
#  Prediction(uid='406', iid='1118', r_ui=3.0, est=3.4584179277884353, details={'was_impossible': False}),
#  Prediction(uid='899', iid='515', r_ui=3.0, est=3.998537025059761, details={'was_impossible': False}),
#  Prediction(uid='13', iid='339', r_ui=3.0, est=2.2946143116566557, details={'was_impossible': False}),
#  Prediction(uid='430', iid='19', r_ui=5.0, est=3.9688724424942117, details={'was_impossible': False}),
#  Prediction(uid='24', iid='729', r_ui=5.0, est=3.7900182981446755, details={'was_impossible': False}),
#  Prediction(uid='634', iid='225', r_ui=3.0, est=2.828303434263611, details={'was_impossible': False}),
#  Prediction(uid='727', iid='89', r_ui=5.0, est=4.166521447524959, details={'was_impossible': False}),
#  Prediction(uid='429', iid='596', r_ui=3.0, est=3.5698175235467664, details={'was_impossible': False}),
#  Prediction(uid='62', iid='127', r_ui=4.0, est=3.9993928452430487, details={'was_impossible': False}),
#  Prediction(uid='771', iid='241', r_ui=1.0, est=3.391258121087371, details={'was_impossible': False}),
#  Prediction(uid='733', iid='762', r_ui=4.0, est=2.9235694215722146, details={'was_impossible': False}),
#  Prediction(uid='139', iid='222', r_ui=3.0, est=3.8608865049466132, details={'was_impossible': False}),
#  Prediction(uid='916', iid='721', r_ui=4.0, est=3.1822967139108997, details={'was_impossible': False}),
#  Prediction(uid='402', iid='204', r_ui=5.0, est=3.773644017037571, details={'was_impossible': False}),
#  Prediction(uid='553', iid='136', r_ui=4.0, est=4.223324069276614, details={'was_impossible': False}),
#  Prediction(uid='62', iid='1073', r_ui=4.0, est=3.716740801830901, details={'was_impossible': False}),
#  Prediction(uid='521', iid='271', r_ui=3.0, est=2.846525844927831, details={'was_impossible': False}),
#  Prediction(uid='488', iid='358', r_ui=3.0, est=2.3964999916334717, details={'was_impossible': False}),
#  Prediction(uid='7', iid='231', r_ui=3.0, est=3.371633283608178, details={'was_impossible': False}),
#  Prediction(uid='346', iid='727', r_ui=1.0, est=3.426835580343521, details={'was_impossible': False}),
#  Prediction(uid='423', iid='823', r_ui=3.0, est=3.049072789410148, details={'was_impossible': False}),
#  Prediction(uid='405', iid='575', r_ui=5.0, est=1.402271044536171, details={'was_impossible': False}),
#  Prediction(uid='385', iid='1158', r_ui=5.0, est=2.6340665161394554, details={'was_impossible': False}),
#  Prediction(uid='630', iid='125', r_ui=3.0, est=3.6026237436643362, details={'was_impossible': False}),
#  Prediction(uid='551', iid='125', r_ui=4.0, est=4.299742896770964, details={'was_impossible': False}),
#  Prediction(uid='727', iid='183', r_ui=3.0, est=4.149841678153687, details={'was_impossible': False}),
#  Prediction(uid='660', iid='810', r_ui=3.0, est=1.9848604388245799, details={'was_impossible': False}),
#  Prediction(uid='552', iid='323', r_ui=2.0, est=2.946200656114359, details={'was_impossible': False}),
#  Prediction(uid='13', iid='604', r_ui=5.0, est=3.4175216596177367, details={'was_impossible': False}),
#  Prediction(uid='642', iid='812', r_ui=4.0, est=3.365417263067772, details={'was_impossible': False}),
#  Prediction(uid='240', iid='269', r_ui=5.0, est=4.274617763233705, details={'was_impossible': False}),
#  Prediction(uid='321', iid='191', r_ui=3.0, est=3.9380028329181713, details={'was_impossible': False}),
#  Prediction(uid='85', iid='921', r_ui=3.0, est=3.720500080651952, details={'was_impossible': False}),
#  Prediction(uid='671', iid='161', r_ui=5.0, est=3.5694084932027055, details={'was_impossible': False}),
#  Prediction(uid='253', iid='97', r_ui=4.0, est=3.990678395991212, details={'was_impossible': False}),
#  Prediction(uid='605', iid='187', r_ui=5.0, est=4.196983155220256, details={'was_impossible': False}),
#  Prediction(uid='472', iid='625', r_ui=4.0, est=4.465966835566959, details={'was_impossible': False}),
#  Prediction(uid='56', iid='449', r_ui=5.0, est=3.6994557381582918, details={'was_impossible': False}),
#  Prediction(uid='881', iid='141', r_ui=3.0, est=3.0705776748511933, details={'was_impossible': False}),
#  Prediction(uid='391', iid='318', r_ui=4.0, est=4.474946539363095, details={'was_impossible': False}),
#  Prediction(uid='601', iid='387', r_ui=3.0, est=2.946650042513225, details={'was_impossible': False}),
#  Prediction(uid='497', iid='475', r_ui=4.0, est=3.656164048614848, details={'was_impossible': False}),
#  Prediction(uid='327', iid='921', r_ui=4.0, est=3.7081577095862253, details={'was_impossible': False}),
#  Prediction(uid='200', iid='1033', r_ui=2.0, est=3.1702094014845064, details={'was_impossible': False}),
#  Prediction(uid='605', iid='64', r_ui=5.0, est=4.447578097292203, details={'was_impossible': False}),
#  Prediction(uid='796', iid='879', r_ui=4.0, est=3.5117929372212844, details={'was_impossible': False}),
#  Prediction(uid='214', iid='216', r_ui=4.0, est=4.005641790460507, details={'was_impossible': False}),
#  Prediction(uid='566', iid='161', r_ui=4.0, est=2.823173381792006, details={'was_impossible': False}),
#  Prediction(uid='653', iid='423', r_ui=2.0, est=2.9920014358322216, details={'was_impossible': False}),
#  Prediction(uid='344', iid='216', r_ui=4.0, est=3.811477533542112, details={'was_impossible': False}),
#  Prediction(uid='151', iid='664', r_ui=5.0, est=4.136648372362618, details={'was_impossible': False}),
#  Prediction(uid='64', iid='751', r_ui=2.0, est=3.1865327593294674, details={'was_impossible': False}),
#  Prediction(uid='554', iid='87', r_ui=4.0, est=3.876197833524901, details={'was_impossible': False}),
#  Prediction(uid='384', iid='327', r_ui=4.0, est=4.035593365987473, details={'was_impossible': False}),
#  Prediction(uid='798', iid='1032', r_ui=3.0, est=2.788159554044257, details={'was_impossible': False}),
#  Prediction(uid='622', iid='90', r_ui=4.0, est=2.9042299949314994, details={'was_impossible': False}),
#  Prediction(uid='719', iid='735', r_ui=5.0, est=3.5371874432122627, details={'was_impossible': False}),
#  Prediction(uid='424', iid='740', r_ui=5.0, est=3.214269769357638, details={'was_impossible': False}),
#  Prediction(uid='294', iid='358', r_ui=2.0, est=2.8205777610317773, details={'was_impossible': False}),
#  Prediction(uid='21', iid='396', r_ui=2.0, est=2.7692919384442205, details={'was_impossible': False}),
#  Prediction(uid='690', iid='197', r_ui=4.0, est=3.67330797232998, details={'was_impossible': False}),
#  Prediction(uid='360', iid='471', r_ui=4.0, est=3.555288530183164, details={'was_impossible': False}),
#  Prediction(uid='734', iid='603', r_ui=4.0, est=3.829778800133726, details={'was_impossible': False}),
#  Prediction(uid='521', iid='174', r_ui=4.0, est=3.590141111666729, details={'was_impossible': False}),
#  Prediction(uid='484', iid='300', r_ui=4.0, est=4.201969918490444, details={'was_impossible': False}),
#  Prediction(uid='128', iid='50', r_ui=4.0, est=4.328924167212222, details={'was_impossible': False}),
#  Prediction(uid='633', iid='921', r_ui=3.0, est=3.5046651381173315, details={'was_impossible': False}),
#  Prediction(uid='854', iid='466', r_ui=3.0, est=3.6267920589847775, details={'was_impossible': False}),
#  Prediction(uid='493', iid='751', r_ui=5.0, est=3.765742852387066, details={'was_impossible': False}),
#  Prediction(uid='504', iid='392', r_ui=5.0, est=3.767350241381326, details={'was_impossible': False}),
#  Prediction(uid='655', iid='318', r_ui=4.0, est=3.4735046212533467, details={'was_impossible': False}),
#  Prediction(uid='650', iid='157', r_ui=3.0, est=2.943220120343315, details={'was_impossible': False}),
#  Prediction(uid='104', iid='273', r_ui=3.0, est=2.727842469972918, details={'was_impossible': False}),
#  Prediction(uid='872', iid='117', r_ui=4.0, est=4.151067017365078, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1170', r_ui=4.0, est=3.4386083252117663, details={'was_impossible': False}),
#  Prediction(uid='146', iid='258', r_ui=4.0, est=3.8825706915230627, details={'was_impossible': False}),
#  Prediction(uid='222', iid='1066', r_ui=1.0, est=2.8195071246857712, details={'was_impossible': False}),
#  Prediction(uid='380', iid='199', r_ui=3.0, est=3.688454949210297, details={'was_impossible': False}),
#  Prediction(uid='618', iid='195', r_ui=3.0, est=3.5430100423947612, details={'was_impossible': False}),
#  Prediction(uid='358', iid='1266', r_ui=4.0, est=3.4550111155179217, details={'was_impossible': False}),
#  Prediction(uid='871', iid='813', r_ui=3.0, est=3.637317152848422, details={'was_impossible': False}),
#  Prediction(uid='234', iid='174', r_ui=3.0, est=4.009905622856453, details={'was_impossible': False}),
#  Prediction(uid='912', iid='15', r_ui=4.0, est=3.6251805220410684, details={'was_impossible': False}),
#  Prediction(uid='75', iid='237', r_ui=2.0, est=3.2493274544281943, details={'was_impossible': False}),
#  Prediction(uid='713', iid='270', r_ui=2.0, est=2.972388838877347, details={'was_impossible': False}),
#  Prediction(uid='251', iid='33', r_ui=3.0, est=3.666008339956978, details={'was_impossible': False}),
#  Prediction(uid='275', iid='199', r_ui=4.0, est=3.796189713341252, details={'was_impossible': False}),
#  Prediction(uid='766', iid='91', r_ui=5.0, est=3.3719938369463023, details={'was_impossible': False}),
#  Prediction(uid='22', iid='204', r_ui=5.0, est=3.6000593016346074, details={'was_impossible': False}),
#  Prediction(uid='487', iid='591', r_ui=2.0, est=4.060809712118816, details={'was_impossible': False}),
#  Prediction(uid='827', iid='316', r_ui=3.0, est=3.9447619583274993, details={'was_impossible': False}),
#  Prediction(uid='919', iid='22', r_ui=5.0, est=3.5284070456160093, details={'was_impossible': False}),
#  Prediction(uid='637', iid='274', r_ui=5.0, est=2.5836751740381603, details={'was_impossible': False}),
#  Prediction(uid='666', iid='856', r_ui=5.0, est=3.79821981031778, details={'was_impossible': False}),
#  Prediction(uid='349', iid='458', r_ui=4.0, est=3.111550977948917, details={'was_impossible': False}),
#  Prediction(uid='880', iid='1197', r_ui=3.0, est=3.8685110185716605, details={'was_impossible': False}),
#  Prediction(uid='30', iid='892', r_ui=4.0, est=2.903325284430957, details={'was_impossible': False}),
#  Prediction(uid='716', iid='213', r_ui=5.0, est=4.050758584746864, details={'was_impossible': False}),
#  Prediction(uid='235', iid='70', r_ui=5.0, est=3.9848857016761148, details={'was_impossible': False}),
#  Prediction(uid='291', iid='1042', r_ui=4.0, est=3.3583926110220568, details={'was_impossible': False}),
#  Prediction(uid='655', iid='311', r_ui=3.0, est=3.2685470716211866, details={'was_impossible': False}),
#  Prediction(uid='387', iid='642', r_ui=4.0, est=3.94431726023191, details={'was_impossible': False}),
#  Prediction(uid='109', iid='31', r_ui=4.0, est=3.623378741917932, details={'was_impossible': False}),
#  Prediction(uid='484', iid='69', r_ui=5.0, est=4.610801789544677, details={'was_impossible': False}),
#  Prediction(uid='393', iid='7', r_ui=4.0, est=3.524074487759061, details={'was_impossible': False}),
#  Prediction(uid='314', iid='53', r_ui=1.0, est=3.246149207655826, details={'was_impossible': False}),
#  Prediction(uid='845', iid='1394', r_ui=4.0, est=2.6863968068671475, details={'was_impossible': False}),
#  Prediction(uid='532', iid='311', r_ui=2.0, est=4.227920221985306, details={'was_impossible': False}),
#  Prediction(uid='195', iid='558', r_ui=3.0, est=3.72118863741009, details={'was_impossible': False}),
#  Prediction(uid='89', iid='151', r_ui=5.0, est=3.844439566201107, details={'was_impossible': False}),
#  Prediction(uid='824', iid='243', r_ui=1.0, est=2.4082438523938468, details={'was_impossible': False}),
#  Prediction(uid='632', iid='11', r_ui=4.0, est=3.6460878751266312, details={'was_impossible': False}),
#  Prediction(uid='393', iid='412', r_ui=3.0, est=2.2191934492490093, details={'was_impossible': False}),
#  Prediction(uid='887', iid='121', r_ui=5.0, est=3.8225893215551423, details={'was_impossible': False}),
#  Prediction(uid='682', iid='412', r_ui=1.0, est=1.9827148773757333, details={'was_impossible': False}),
#  Prediction(uid='406', iid='210', r_ui=5.0, est=4.024939746149709, details={'was_impossible': False}),
#  Prediction(uid='795', iid='552', r_ui=2.0, est=2.776182910228825, details={'was_impossible': False}),
#  Prediction(uid='774', iid='546', r_ui=1.0, est=1.6487211327306426, details={'was_impossible': False}),
#  Prediction(uid='47', iid='304', r_ui=3.0, est=3.708007690262681, details={'was_impossible': False}),
#  Prediction(uid='514', iid='15', r_ui=4.0, est=4.04919575607582, details={'was_impossible': False}),
#  Prediction(uid='804', iid='175', r_ui=4.0, est=3.87716766288467, details={'was_impossible': False}),
#  Prediction(uid='804', iid='1056', r_ui=4.0, est=3.322900172429821, details={'was_impossible': False}),
#  Prediction(uid='21', iid='243', r_ui=2.0, est=1.8574292402020978, details={'was_impossible': False}),
#  Prediction(uid='618', iid='778', r_ui=3.0, est=3.2025688019778222, details={'was_impossible': False}),
#  Prediction(uid='151', iid='222', r_ui=5.0, est=3.8901370641924773, details={'was_impossible': False}),
#  Prediction(uid='224', iid='583', r_ui=1.0, est=2.8518702508795233, details={'was_impossible': False}),
#  Prediction(uid='283', iid='709', r_ui=5.0, est=4.752361166479669, details={'was_impossible': False}),
#  Prediction(uid='504', iid='185', r_ui=5.0, est=4.403556525006617, details={'was_impossible': False}),
#  Prediction(uid='553', iid='135', r_ui=4.0, est=4.216244680411914, details={'was_impossible': False}),
#  Prediction(uid='846', iid='203', r_ui=5.0, est=3.819621825365987, details={'was_impossible': False}),
#  Prediction(uid='773', iid='52', r_ui=3.0, est=3.450823033108383, details={'was_impossible': False}),
#  Prediction(uid='385', iid='384', r_ui=1.0, est=2.7074872055224035, details={'was_impossible': False}),
#  Prediction(uid='346', iid='720', r_ui=2.0, est=2.9377074803901673, details={'was_impossible': False}),
#  Prediction(uid='373', iid='366', r_ui=4.0, est=3.6571438536019065, details={'was_impossible': False}),
#  Prediction(uid='881', iid='474', r_ui=3.0, est=3.3948253242258533, details={'was_impossible': False}),
#  Prediction(uid='537', iid='845', r_ui=2.0, est=2.5448112865109684, details={'was_impossible': False}),
#  Prediction(uid='474', iid='50', r_ui=5.0, est=4.905648819700413, details={'was_impossible': False}),
#  Prediction(uid='293', iid='77', r_ui=2.0, est=2.7127683994053853, details={'was_impossible': False}),
#  Prediction(uid='542', iid='435', r_ui=4.0, est=3.911610154341294, details={'was_impossible': False}),
#  Prediction(uid='262', iid='111', r_ui=4.0, est=2.976853123434253, details={'was_impossible': False}),
#  Prediction(uid='109', iid='1210', r_ui=3.0, est=2.696027679021625, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1164', r_ui=3.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='847', iid='96', r_ui=4.0, est=3.5867683679415667, details={'was_impossible': False}),
#  Prediction(uid='625', iid='640', r_ui=3.0, est=2.6324058918356994, details={'was_impossible': False}),
#  Prediction(uid='246', iid='178', r_ui=5.0, est=3.689430315459794, details={'was_impossible': False}),
#  Prediction(uid='425', iid='24', r_ui=2.0, est=3.276841078898502, details={'was_impossible': False}),
#  Prediction(uid='749', iid='712', r_ui=3.0, est=3.481804563714031, details={'was_impossible': False}),
#  Prediction(uid='586', iid='227', r_ui=2.0, est=2.8400125653067456, details={'was_impossible': False}),
#  Prediction(uid='410', iid='754', r_ui=3.0, est=3.0062892187740813, details={'was_impossible': False}),
#  Prediction(uid='332', iid='9', r_ui=4.0, est=4.355225807183338, details={'was_impossible': False}),
#  Prediction(uid='185', iid='47', r_ui=4.0, est=3.5093809126486777, details={'was_impossible': False}),
#  Prediction(uid='582', iid='826', r_ui=3.0, est=2.388736570145487, details={'was_impossible': False}),
#  Prediction(uid='130', iid='217', r_ui=3.0, est=4.120886820199413, details={'was_impossible': False}),
#  Prediction(uid='537', iid='426', r_ui=1.0, est=2.3944034189281425, details={'was_impossible': False}),
#  Prediction(uid='295', iid='380', r_ui=4.0, est=4.105005609328543, details={'was_impossible': False}),
#  Prediction(uid='756', iid='151', r_ui=4.0, est=3.442766305806148, details={'was_impossible': False}),
#  Prediction(uid='749', iid='826', r_ui=3.0, est=2.7509726478558414, details={'was_impossible': False}),
#  Prediction(uid='405', iid='657', r_ui=1.0, est=2.509340589713835, details={'was_impossible': False}),
#  Prediction(uid='622', iid='1407', r_ui=1.0, est=2.8801122214555983, details={'was_impossible': False}),
#  Prediction(uid='425', iid='825', r_ui=2.0, est=2.405394215931065, details={'was_impossible': False}),
#  Prediction(uid='372', iid='56', r_ui=4.0, est=4.892895830506719, details={'was_impossible': False}),
#  Prediction(uid='338', iid='1124', r_ui=4.0, est=3.4260814151858363, details={'was_impossible': False}),
#  Prediction(uid='795', iid='568', r_ui=3.0, est=2.9074827160026073, details={'was_impossible': False}),
#  Prediction(uid='99', iid='694', r_ui=1.0, est=4.108345103478798, details={'was_impossible': False}),
#  Prediction(uid='717', iid='980', r_ui=4.0, est=3.588950844128276, details={'was_impossible': False}),
#  Prediction(uid='470', iid='952', r_ui=3.0, est=3.094752543913258, details={'was_impossible': False}),
#  Prediction(uid='268', iid='153', r_ui=5.0, est=3.544195216067214, details={'was_impossible': False}),
#  Prediction(uid='425', iid='853', r_ui=4.0, est=3.3992611593776694, details={'was_impossible': False}),
#  Prediction(uid='457', iid='566', r_ui=4.0, est=4.208475179587069, details={'was_impossible': False}),
#  Prediction(uid='73', iid='433', r_ui=4.0, est=3.5577254584863884, details={'was_impossible': False}),
#  Prediction(uid='397', iid='665', r_ui=3.0, est=2.8872312275159437, details={'was_impossible': False}),
#  Prediction(uid='466', iid='357', r_ui=4.0, est=3.9069491341418994, details={'was_impossible': False}),
#  Prediction(uid='389', iid='1114', r_ui=2.0, est=3.613642159240039, details={'was_impossible': False}),
#  Prediction(uid='328', iid='903', r_ui=3.0, est=3.320441721525511, details={'was_impossible': False}),
#  Prediction(uid='378', iid='742', r_ui=4.0, est=3.298997488073128, details={'was_impossible': False}),
#  Prediction(uid='65', iid='211', r_ui=4.0, est=4.168469882299477, details={'was_impossible': False}),
#  Prediction(uid='333', iid='98', r_ui=4.0, est=4.424619911447784, details={'was_impossible': False}),
#  Prediction(uid='886', iid='240', r_ui=3.0, est=2.807916600788763, details={'was_impossible': False}),
#  Prediction(uid='897', iid='673', r_ui=5.0, est=3.9452393045708263, details={'was_impossible': False}),
#  Prediction(uid='224', iid='720', r_ui=4.0, est=2.992579298937543, details={'was_impossible': False}),
#  Prediction(uid='934', iid='526', r_ui=2.0, est=3.9564499235206454, details={'was_impossible': False}),
#  Prediction(uid='181', iid='931', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='839', iid='50', r_ui=5.0, est=4.277921126352281, details={'was_impossible': False}),
#  Prediction(uid='782', iid='322', r_ui=4.0, est=3.009080526677883, details={'was_impossible': False}),
#  Prediction(uid='181', iid='263', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='880', iid='40', r_ui=2.0, est=3.1596145769376878, details={'was_impossible': False}),
#  Prediction(uid='505', iid='588', r_ui=5.0, est=3.337312138798658, details={'was_impossible': False}),
#  Prediction(uid='207', iid='433', r_ui=3.0, est=3.0478688969087546, details={'was_impossible': False}),
#  Prediction(uid='500', iid='619', r_ui=3.0, est=3.2375897237900686, details={'was_impossible': False}),
#  Prediction(uid='181', iid='360', r_ui=1.0, est=1.81904420740059, details={'was_impossible': False}),
#  Prediction(uid='922', iid='62', r_ui=3.0, est=2.6482581823562503, details={'was_impossible': False}),
#  Prediction(uid='815', iid='735', r_ui=5.0, est=3.9060806987580787, details={'was_impossible': False}),
#  Prediction(uid='782', iid='937', r_ui=1.0, est=3.2092639555274776, details={'was_impossible': False}),
#  Prediction(uid='894', iid='638', r_ui=3.0, est=4.021074457710565, details={'was_impossible': False}),
#  Prediction(uid='551', iid='698', r_ui=4.0, est=3.607347285689492, details={'was_impossible': False}),
#  Prediction(uid='246', iid='1101', r_ui=5.0, est=3.1714700377739216, details={'was_impossible': False}),
#  Prediction(uid='131', iid='275', r_ui=2.0, est=3.9458380882018216, details={'was_impossible': False}),
#  Prediction(uid='606', iid='248', r_ui=5.0, est=3.8164820598857814, details={'was_impossible': False}),
#  Prediction(uid='854', iid='191', r_ui=4.0, est=4.119166001095413, details={'was_impossible': False}),
#  Prediction(uid='889', iid='3', r_ui=4.0, est=3.3975475320913886, details={'was_impossible': False}),
#  Prediction(uid='547', iid='294', r_ui=1.0, est=3.1537368521867952, details={'was_impossible': False}),
#  Prediction(uid='211', iid='303', r_ui=3.0, est=3.6640141079278052, details={'was_impossible': False}),
#  Prediction(uid='883', iid='707', r_ui=3.0, est=4.424183467701283, details={'was_impossible': False}),
#  Prediction(uid='823', iid='228', r_ui=3.0, est=3.8035109654790458, details={'was_impossible': False}),
#  Prediction(uid='889', iid='173', r_ui=5.0, est=3.860211556880295, details={'was_impossible': False}),
#  Prediction(uid='293', iid='117', r_ui=3.0, est=2.7550606941853477, details={'was_impossible': False}),
#  Prediction(uid='723', iid='164', r_ui=4.0, est=3.161715220790546, details={'was_impossible': False}),
#  Prediction(uid='313', iid='720', r_ui=2.0, est=2.7719959819803686, details={'was_impossible': False}),
#  Prediction(uid='87', iid='8', r_ui=5.0, est=4.356583548222968, details={'was_impossible': False}),
#  Prediction(uid='305', iid='215', r_ui=2.0, est=3.0793360576085513, details={'was_impossible': False}),
#  Prediction(uid='588', iid='1411', r_ui=1.0, est=2.825554415293305, details={'was_impossible': False}),
#  Prediction(uid='83', iid='50', r_ui=3.0, est=4.425886046482924, details={'was_impossible': False}),
#  Prediction(uid='81', iid='432', r_ui=2.0, est=3.3278542738281316, details={'was_impossible': False}),
#  Prediction(uid='372', iid='77', r_ui=5.0, est=4.344127107067182, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1512', r_ui=5.0, est=3.8891600982953105, details={'was_impossible': False}),
#  Prediction(uid='194', iid='125', r_ui=2.0, est=2.797974897577828, details={'was_impossible': False}),
#  Prediction(uid='745', iid='510', r_ui=3.0, est=2.9236400775729834, details={'was_impossible': False}),
#  Prediction(uid='749', iid='191', r_ui=4.0, est=4.411315607925226, details={'was_impossible': False}),
#  Prediction(uid='821', iid='117', r_ui=3.0, est=4.466763194380747, details={'was_impossible': False}),
#  Prediction(uid='552', iid='926', r_ui=2.0, est=2.7918051287631585, details={'was_impossible': False}),
#  Prediction(uid='541', iid='659', r_ui=5.0, est=4.274579716229882, details={'was_impossible': False}),
#  Prediction(uid='682', iid='735', r_ui=4.0, est=3.722870695864219, details={'was_impossible': False}),
#  Prediction(uid='424', iid='127', r_ui=4.0, est=3.531692208628126, details={'was_impossible': False}),
#  Prediction(uid='854', iid='264', r_ui=1.0, est=2.4436303218530555, details={'was_impossible': False}),
#  Prediction(uid='389', iid='492', r_ui=5.0, est=3.9661369169219647, details={'was_impossible': False}),
#  Prediction(uid='354', iid='208', r_ui=4.0, est=4.0664752850361845, details={'was_impossible': False}),
#  Prediction(uid='527', iid='127', r_ui=5.0, est=4.0702553859632395, details={'was_impossible': False}),
#  Prediction(uid='378', iid='302', r_ui=5.0, est=4.072367475267586, details={'was_impossible': False}),
#  Prediction(uid='903', iid='1009', r_ui=4.0, est=3.6560126807553437, details={'was_impossible': False}),
#  Prediction(uid='484', iid='15', r_ui=5.0, est=4.281835196862092, details={'was_impossible': False}),
#  Prediction(uid='62', iid='7', r_ui=4.0, est=3.3572049921190397, details={'was_impossible': False}),
#  Prediction(uid='387', iid='692', r_ui=1.0, est=2.636973161111362, details={'was_impossible': False}),
#  Prediction(uid='641', iid='270', r_ui=3.0, est=4.034574756038233, details={'was_impossible': False}),
#  Prediction(uid='164', iid='9', r_ui=4.0, est=4.205058055676967, details={'was_impossible': False}),
#  Prediction(uid='608', iid='204', r_ui=4.0, est=4.260034225198324, details={'was_impossible': False}),
#  Prediction(uid='459', iid='472', r_ui=5.0, est=3.050257373615033, details={'was_impossible': False}),
#  Prediction(uid='566', iid='122', r_ui=2.0, est=2.361443402512148, details={'was_impossible': False}),
#  Prediction(uid='398', iid='4', r_ui=2.0, est=3.513284570030176, details={'was_impossible': False}),
#  Prediction(uid='407', iid='274', r_ui=3.0, est=3.261002426009337, details={'was_impossible': False}),
#  Prediction(uid='144', iid='273', r_ui=4.0, est=3.597520769051772, details={'was_impossible': False}),
#  Prediction(uid='523', iid='582', r_ui=4.0, est=4.3765497973076215, details={'was_impossible': False}),
#  Prediction(uid='613', iid='607', r_ui=4.0, est=4.423320635326384, details={'was_impossible': False}),
#  Prediction(uid='416', iid='690', r_ui=5.0, est=4.024405338537593, details={'was_impossible': False}),
#  Prediction(uid='610', iid='317', r_ui=3.0, est=3.998575548117878, details={'was_impossible': False}),
#  Prediction(uid='758', iid='91', r_ui=4.0, est=3.8822898427706862, details={'was_impossible': False}),
#  Prediction(uid='308', iid='58', r_ui=3.0, est=3.4808806384748636, details={'was_impossible': False}),
#  Prediction(uid='334', iid='620', r_ui=2.0, est=2.80249395799989, details={'was_impossible': False}),
#  Prediction(uid='833', iid='506', r_ui=2.0, est=3.165446359659944, details={'was_impossible': False}),
#  Prediction(uid='70', iid='231', r_ui=3.0, est=2.6569415293884897, details={'was_impossible': False}),
#  Prediction(uid='399', iid='1035', r_ui=3.0, est=2.8971379960328836, details={'was_impossible': False}),
#  Prediction(uid='13', iid='64', r_ui=5.0, est=4.5223898815787935, details={'was_impossible': False}),
#  Prediction(uid='534', iid='93', r_ui=1.0, est=4.086656449440079, details={'was_impossible': False}),
#  Prediction(uid='843', iid='708', r_ui=2.0, est=2.7990909857118353, details={'was_impossible': False}),
#  Prediction(uid='639', iid='714', r_ui=2.0, est=2.936105647675556, details={'was_impossible': False}),
#  Prediction(uid='663', iid='321', r_ui=5.0, est=3.44546983256564, details={'was_impossible': False}),
#  Prediction(uid='189', iid='1402', r_ui=4.0, est=3.7051920197950685, details={'was_impossible': False}),
#  Prediction(uid='457', iid='172', r_ui=5.0, est=4.796506311329, details={'was_impossible': False}),
#  Prediction(uid='640', iid='580', r_ui=5.0, est=4.006632128609446, details={'was_impossible': False}),
#  Prediction(uid='94', iid='356', r_ui=4.0, est=3.438112415839069, details={'was_impossible': False}),
#  Prediction(uid='504', iid='187', r_ui=3.0, est=4.284636764715559, details={'was_impossible': False}),
#  Prediction(uid='436', iid='288', r_ui=4.0, est=3.4446123974907987, details={'was_impossible': False}),
#  Prediction(uid='541', iid='1030', r_ui=3.0, est=2.679023819786142, details={'was_impossible': False}),
#  Prediction(uid='551', iid='168', r_ui=5.0, est=3.9367348375103273, details={'was_impossible': False}),
#  Prediction(uid='703', iid='15', r_ui=5.0, est=3.8501586725494996, details={'was_impossible': False}),
#  Prediction(uid='521', iid='228', r_ui=4.0, est=3.478645047733271, details={'was_impossible': False}),
#  Prediction(uid='510', iid='325', r_ui=1.0, est=2.4057370985669513, details={'was_impossible': False}),
#  Prediction(uid='463', iid='689', r_ui=2.0, est=2.646454362082326, details={'was_impossible': False}),
#  Prediction(uid='312', iid='499', r_ui=4.0, est=4.252627666034749, details={'was_impossible': False}),
#  Prediction(uid='533', iid='357', r_ui=3.0, est=4.138753235431307, details={'was_impossible': False}),
#  Prediction(uid='393', iid='794', r_ui=4.0, est=3.6959793717923772, details={'was_impossible': False}),
#  Prediction(uid='642', iid='748', r_ui=5.0, est=4.334367952488353, details={'was_impossible': False}),
#  Prediction(uid='851', iid='1291', r_ui=2.0, est=3.263421406744639, details={'was_impossible': False}),
#  Prediction(uid='128', iid='507', r_ui=4.0, est=4.17573507443891, details={'was_impossible': False}),
#  Prediction(uid='568', iid='653', r_ui=4.0, est=3.364692399097952, details={'was_impossible': False}),
#  Prediction(uid='325', iid='1', r_ui=2.0, est=3.3620083634808857, details={'was_impossible': False}),
#  Prediction(uid='345', iid='161', r_ui=3.0, est=3.360865258718832, details={'was_impossible': False}),
#  Prediction(uid='741', iid='280', r_ui=3.0, est=3.2549287098511464, details={'was_impossible': False}),
#  Prediction(uid='545', iid='222', r_ui=4.0, est=3.7089326259940307, details={'was_impossible': False}),
#  Prediction(uid='778', iid='144', r_ui=4.0, est=3.4502283561179974, details={'was_impossible': False}),
#  Prediction(uid='874', iid='137', r_ui=4.0, est=3.585684537985624, details={'was_impossible': False}),
#  Prediction(uid='897', iid='1254', r_ui=2.0, est=3.079330491062763, details={'was_impossible': False}),
#  Prediction(uid='385', iid='1143', r_ui=4.0, est=3.392188110813253, details={'was_impossible': False}),
#  Prediction(uid='487', iid='43', r_ui=3.0, est=3.2304936489398615, details={'was_impossible': False}),
#  Prediction(uid='425', iid='269', r_ui=4.0, est=3.6326706639346225, details={'was_impossible': False}),
#  Prediction(uid='758', iid='412', r_ui=5.0, est=2.5746718538962727, details={'was_impossible': False}),
#  Prediction(uid='313', iid='191', r_ui=5.0, est=3.9716445246304413, details={'was_impossible': False}),
#  Prediction(uid='11', iid='414', r_ui=3.0, est=3.5169268623533116, details={'was_impossible': False}),
#  Prediction(uid='225', iid='1443', r_ui=4.0, est=4.158801215908535, details={'was_impossible': False}),
#  Prediction(uid='849', iid='676', r_ui=5.0, est=4.157807310428181, details={'was_impossible': False}),
#  Prediction(uid='616', iid='339', r_ui=3.0, est=3.452373320027604, details={'was_impossible': False}),
#  Prediction(uid='109', iid='131', r_ui=1.0, est=3.333028336598546, details={'was_impossible': False}),
#  Prediction(uid='548', iid='164', r_ui=5.0, est=4.293528530274765, details={'was_impossible': False}),
#  Prediction(uid='455', iid='1034', r_ui=2.0, est=2.54811649449191, details={'was_impossible': False}),
#  Prediction(uid='289', iid='849', r_ui=4.0, est=2.404981449434412, details={'was_impossible': False}),
#  Prediction(uid='896', iid='148', r_ui=2.0, est=2.5767786145053018, details={'was_impossible': False}),
#  Prediction(uid='38', iid='294', r_ui=5.0, est=4.2103787726898325, details={'was_impossible': False}),
#  Prediction(uid='194', iid='385', r_ui=2.0, est=2.9978059492592988, details={'was_impossible': False}),
#  Prediction(uid='385', iid='235', r_ui=5.0, est=3.3606945697138446, details={'was_impossible': False}),
#  Prediction(uid='553', iid='131', r_ui=5.0, est=4.259345987240872, details={'was_impossible': False}),
#  Prediction(uid='896', iid='184', r_ui=3.0, est=2.5120291922243583, details={'was_impossible': False}),
#  Prediction(uid='940', iid='315', r_ui=4.0, est=3.7426865333781874, details={'was_impossible': False}),
#  Prediction(uid='178', iid='144', r_ui=4.0, est=4.171832231772436, details={'was_impossible': False}),
#  Prediction(uid='482', iid='311', r_ui=4.0, est=4.019569571786215, details={'was_impossible': False}),
#  Prediction(uid='327', iid='663', r_ui=4.0, est=3.4939392859810945, details={'was_impossible': False}),
#  Prediction(uid='601', iid='173', r_ui=5.0, est=3.6457261004448416, details={'was_impossible': False}),
#  Prediction(uid='345', iid='150', r_ui=5.0, est=3.9739330687377414, details={'was_impossible': False}),
#  Prediction(uid='761', iid='1014', r_ui=1.0, est=2.8598655281921546, details={'was_impossible': False}),
#  Prediction(uid='790', iid='1119', r_ui=4.0, est=3.249028861022251, details={'was_impossible': False}),
#  Prediction(uid='489', iid='989', r_ui=3.0, est=3.7079728315508373, details={'was_impossible': False}),
#  Prediction(uid='38', iid='318', r_ui=3.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1496', r_ui=3.0, est=3.328790123790751, details={'was_impossible': False}),
#  Prediction(uid='923', iid='591', r_ui=5.0, est=4.464036077590131, details={'was_impossible': False}),
#  Prediction(uid='323', iid='215', r_ui=5.0, est=3.765946091258933, details={'was_impossible': False}),
#  Prediction(uid='376', iid='181', r_ui=4.0, est=4.059563754059492, details={'was_impossible': False}),
#  Prediction(uid='927', iid='541', r_ui=5.0, est=3.4751634919651444, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1286', r_ui=5.0, est=3.767790567273971, details={'was_impossible': False}),
#  Prediction(uid='268', iid='655', r_ui=4.0, est=2.6946190852690632, details={'was_impossible': False}),
#  Prediction(uid='64', iid='196', r_ui=4.0, est=3.8847563389768727, details={'was_impossible': False}),
#  Prediction(uid='271', iid='427', r_ui=5.0, est=4.254926847735174, details={'was_impossible': False}),
#  Prediction(uid='122', iid='511', r_ui=5.0, est=4.540174664536905, details={'was_impossible': False}),
#  Prediction(uid='167', iid='404', r_ui=3.0, est=3.705295859490248, details={'was_impossible': False}),
#  Prediction(uid='580', iid='281', r_ui=2.0, est=3.3295408475269417, details={'was_impossible': False}),
#  Prediction(uid='95', iid='510', r_ui=4.0, est=4.0582945495666065, details={'was_impossible': False}),
#  Prediction(uid='615', iid='237', r_ui=4.0, est=3.427262823883577, details={'was_impossible': False}),
#  Prediction(uid='663', iid='25', r_ui=4.0, est=3.7904445011100893, details={'was_impossible': False}),
#  Prediction(uid='883', iid='517', r_ui=4.0, est=4.384124859950398, details={'was_impossible': False}),
#  Prediction(uid='189', iid='30', r_ui=4.0, est=4.185063992761506, details={'was_impossible': False}),
#  Prediction(uid='735', iid='333', r_ui=4.0, est=3.070068953220371, details={'was_impossible': False}),
#  Prediction(uid='711', iid='272', r_ui=5.0, est=4.445717290974719, details={'was_impossible': False}),
#  Prediction(uid='874', iid='124', r_ui=4.0, est=3.716635508760206, details={'was_impossible': False}),
#  Prediction(uid='796', iid='525', r_ui=4.0, est=3.9718210250593113, details={'was_impossible': False}),
#  Prediction(uid='668', iid='596', r_ui=3.0, est=3.0919180789537704, details={'was_impossible': False}),
#  Prediction(uid='533', iid='9', r_ui=4.0, est=3.218035492227382, details={'was_impossible': False}),
#  Prediction(uid='851', iid='248', r_ui=4.0, est=3.6969406736417, details={'was_impossible': False}),
#  Prediction(uid='360', iid='14', r_ui=5.0, est=4.163110552965349, details={'was_impossible': False}),
#  Prediction(uid='62', iid='181', r_ui=4.0, est=4.030831057960801, details={'was_impossible': False}),
#  Prediction(uid='579', iid='514', r_ui=3.0, est=3.6361079917431756, details={'was_impossible': False}),
#  Prediction(uid='158', iid='745', r_ui=4.0, est=3.863681756578039, details={'was_impossible': False}),
#  Prediction(uid='119', iid='1052', r_ui=4.0, est=2.586820993374387, details={'was_impossible': False}),
#  Prediction(uid='275', iid='162', r_ui=3.0, est=3.294606718510863, details={'was_impossible': False}),
#  Prediction(uid='503', iid='277', r_ui=4.0, est=3.566574330787072, details={'was_impossible': False}),
#  Prediction(uid='710', iid='496', r_ui=4.0, est=4.131037264914241, details={'was_impossible': False}),
#  Prediction(uid='660', iid='550', r_ui=2.0, est=2.7226245856912827, details={'was_impossible': False}),
#  Prediction(uid='42', iid='151', r_ui=4.0, est=3.258198578220827, details={'was_impossible': False}),
#  Prediction(uid='479', iid='147', r_ui=3.0, est=3.065455112604705, details={'was_impossible': False}),
#  Prediction(uid='574', iid='887', r_ui=4.0, est=3.3935945966980707, details={'was_impossible': False}),
#  Prediction(uid='13', iid='655', r_ui=5.0, est=3.830407304095369, details={'was_impossible': False}),
#  Prediction(uid='593', iid='220', r_ui=3.0, est=3.3706300153149864, details={'was_impossible': False}),
#  Prediction(uid='524', iid='526', r_ui=3.0, est=4.223647713816623, details={'was_impossible': False}),
#  Prediction(uid='244', iid='721', r_ui=5.0, est=3.4840049857036344, details={'was_impossible': False}),
#  Prediction(uid='774', iid='567', r_ui=1.0, est=1.6514579634672248, details={'was_impossible': False}),
#  Prediction(uid='848', iid='132', r_ui=5.0, est=4.651759756029101, details={'was_impossible': False}),
#  Prediction(uid='851', iid='435', r_ui=4.0, est=4.125419440706149, details={'was_impossible': False}),
#  Prediction(uid='198', iid='58', r_ui=3.0, est=3.1085916396505024, details={'was_impossible': False}),
#  Prediction(uid='286', iid='210', r_ui=5.0, est=3.9868632504308255, details={'was_impossible': False}),
#  Prediction(uid='608', iid='753', r_ui=5.0, est=3.760267116022314, details={'was_impossible': False}),
#  Prediction(uid='303', iid='379', r_ui=4.0, est=3.0162543986656223, details={'was_impossible': False}),
#  Prediction(uid='271', iid='221', r_ui=3.0, est=3.709195542529533, details={'was_impossible': False}),
#  Prediction(uid='492', iid='650', r_ui=2.0, est=3.011208238084078, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1278', r_ui=4.0, est=2.994561761173389, details={'was_impossible': False}),
#  Prediction(uid='864', iid='609', r_ui=3.0, est=3.889985882769141, details={'was_impossible': False}),
#  Prediction(uid='763', iid='357', r_ui=4.0, est=4.452140127137441, details={'was_impossible': False}),
#  Prediction(uid='894', iid='45', r_ui=4.0, est=3.904153077909934, details={'was_impossible': False}),
#  Prediction(uid='272', iid='201', r_ui=3.0, est=3.7895309700994195, details={'was_impossible': False}),
#  Prediction(uid='264', iid='275', r_ui=5.0, est=4.417083604949153, details={'was_impossible': False}),
#  Prediction(uid='286', iid='278', r_ui=5.0, est=3.7236123256116844, details={'was_impossible': False}),
#  Prediction(uid='190', iid='508', r_ui=3.0, est=3.6919671845939335, details={'was_impossible': False}),
#  Prediction(uid='80', iid='194', r_ui=3.0, est=4.174674515418372, details={'was_impossible': False}),
#  Prediction(uid='916', iid='222', r_ui=3.0, est=3.4691357316265767, details={'was_impossible': False}),
#  Prediction(uid='532', iid='495', r_ui=4.0, est=4.473172200029862, details={'was_impossible': False}),
#  Prediction(uid='929', iid='136', r_ui=3.0, est=3.8994894382112286, details={'was_impossible': False}),
#  Prediction(uid='178', iid='731', r_ui=4.0, est=3.471888254194396, details={'was_impossible': False}),
#  Prediction(uid='327', iid='537', r_ui=4.0, est=3.8484712175114986, details={'was_impossible': False}),
#  Prediction(uid='591', iid='172', r_ui=3.0, est=4.126607420000668, details={'was_impossible': False}),
#  Prediction(uid='679', iid='268', r_ui=4.0, est=3.577563245795032, details={'was_impossible': False}),
#  Prediction(uid='795', iid='429', r_ui=3.0, est=3.691547147625531, details={'was_impossible': False}),
#  Prediction(uid='234', iid='321', r_ui=2.0, est=2.9337820209410346, details={'was_impossible': False}),
#  Prediction(uid='698', iid='275', r_ui=4.0, est=3.328713078805201, details={'was_impossible': False}),
#  Prediction(uid='385', iid='503', r_ui=3.0, est=3.2800000522976274, details={'was_impossible': False}),
#  Prediction(uid='268', iid='746', r_ui=3.0, est=3.3100318217362394, details={'was_impossible': False}),
#  Prediction(uid='682', iid='774', r_ui=4.0, est=3.2184599509256477, details={'was_impossible': False}),
#  Prediction(uid='244', iid='287', r_ui=3.0, est=4.049480209585509, details={'was_impossible': False}),
#  Prediction(uid='387', iid='175', r_ui=5.0, est=4.49628329894678, details={'was_impossible': False}),
#  Prediction(uid='707', iid='194', r_ui=4.0, est=3.8409206735024655, details={'was_impossible': False}),
#  Prediction(uid='216', iid='189', r_ui=3.0, est=4.2448627127402405, details={'was_impossible': False}),
#  Prediction(uid='524', iid='523', r_ui=4.0, est=4.006237425311332, details={'was_impossible': False}),
#  Prediction(uid='486', iid='288', r_ui=4.0, est=2.930341338321666, details={'was_impossible': False}),
#  Prediction(uid='395', iid='252', r_ui=3.0, est=3.2152207862968383, details={'was_impossible': False}),
#  Prediction(uid='620', iid='78', r_ui=4.0, est=3.411276981210599, details={'was_impossible': False}),
#  Prediction(uid='892', iid='64', r_ui=4.0, est=4.713068300611333, details={'was_impossible': False}),
#  Prediction(uid='345', iid='241', r_ui=4.0, est=3.820469041593945, details={'was_impossible': False}),
#  Prediction(uid='593', iid='597', r_ui=2.0, est=3.358326411703339, details={'was_impossible': False}),
#  Prediction(uid='895', iid='1', r_ui=4.0, est=4.579467919633467, details={'was_impossible': False}),
#  Prediction(uid='18', iid='237', r_ui=3.0, est=3.8531262381800393, details={'was_impossible': False}),
#  Prediction(uid='60', iid='151', r_ui=5.0, est=4.0618458296934765, details={'was_impossible': False}),
#  Prediction(uid='417', iid='39', r_ui=3.0, est=2.9974044471051093, details={'was_impossible': False}),
#  Prediction(uid='823', iid='721', r_ui=4.0, est=3.9186502682004614, details={'was_impossible': False}),
#  Prediction(uid='286', iid='231', r_ui=3.0, est=2.9977988795875654, details={'was_impossible': False}),
#  Prediction(uid='389', iid='47', r_ui=4.0, est=3.8995755169455966, details={'was_impossible': False}),
#  Prediction(uid='298', iid='1142', r_ui=4.0, est=4.109681002914699, details={'was_impossible': False}),
#  Prediction(uid='216', iid='200', r_ui=5.0, est=4.131118053955941, details={'was_impossible': False}),
#  Prediction(uid='236', iid='204', r_ui=3.0, est=3.722887937351466, details={'was_impossible': False}),
#  Prediction(uid='393', iid='808', r_ui=4.0, est=3.151361967888698, details={'was_impossible': False}),
#  Prediction(uid='704', iid='354', r_ui=4.0, est=3.4261178687169473, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1189', r_ui=5.0, est=3.6828878059544436, details={'was_impossible': False}),
#  Prediction(uid='349', iid='696', r_ui=3.0, est=2.9516309378582433, details={'was_impossible': False}),
#  Prediction(uid='90', iid='174', r_ui=5.0, est=4.523348703849574, details={'was_impossible': False}),
#  Prediction(uid='828', iid='1466', r_ui=4.0, est=2.803030174744103, details={'was_impossible': False}),
#  Prediction(uid='286', iid='1239', r_ui=3.0, est=2.995964228409508, details={'was_impossible': False}),
#  Prediction(uid='279', iid='275', r_ui=3.0, est=3.7578053592753498, details={'was_impossible': False}),
#  Prediction(uid='451', iid='322', r_ui=4.0, est=2.880344287339562, details={'was_impossible': False}),
#  Prediction(uid='405', iid='959', r_ui=1.0, est=3.020703526079304, details={'was_impossible': False}),
#  Prediction(uid='718', iid='815', r_ui=4.0, est=3.4242469812825505, details={'was_impossible': False}),
# ...
#  Prediction(uid='264', iid='672', r_ui=3.0, est=3.1405871270623007, details={'was_impossible': False}),
#  Prediction(uid='405', iid='48', r_ui=1.0, est=1.7949263119944718, details={'was_impossible': False}),
#  Prediction(uid='429', iid='961', r_ui=3.0, est=3.4183730821584035, details={'was_impossible': False}),
#  Prediction(uid='215', iid='164', r_ui=3.0, est=3.414940801157405, details={'was_impossible': False}),
#  Prediction(uid='569', iid='340', r_ui=4.0, est=3.840925543603446, details={'was_impossible': False}),
#  Prediction(uid='621', iid='804', r_ui=4.0, est=3.377565389008908, details={'was_impossible': False}),
#  Prediction(uid='188', iid='22', r_ui=5.0, est=4.015249711185298, details={'was_impossible': False}),
#  Prediction(uid='360', iid='144', r_ui=2.0, est=3.734239550942668, details={'was_impossible': False}),
#  Prediction(uid='293', iid='132', r_ui=4.0, est=3.519012967844617, details={'was_impossible': False}),
#  Prediction(uid='399', iid='343', r_ui=2.0, est=2.707918785979949, details={'was_impossible': False}),
#  Prediction(uid='456', iid='86', r_ui=2.0, est=3.9183552153663297, details={'was_impossible': False}),
#  Prediction(uid='407', iid='157', r_ui=2.0, est=3.605779877071576, details={'was_impossible': False}),
#  Prediction(uid='707', iid='100', r_ui=5.0, est=4.145803656523481, details={'was_impossible': False}),
#  Prediction(uid='328', iid='750', r_ui=4.0, est=4.192395824483774, details={'was_impossible': False}),
#  Prediction(uid='488', iid='173', r_ui=4.0, est=3.7072987814632, details={'was_impossible': False}),
#  Prediction(uid='868', iid='229', r_ui=3.0, est=2.42628061001808, details={'was_impossible': False}),
#  Prediction(uid='151', iid='531', r_ui=3.0, est=4.246168907193487, details={'was_impossible': False}),
#  Prediction(uid='848', iid='523', r_ui=5.0, est=4.475195241381727, details={'was_impossible': False}),
#  Prediction(uid='454', iid='95', r_ui=2.0, est=3.3575991244515206, details={'was_impossible': False}),
#  Prediction(uid='368', iid='7', r_ui=4.0, est=3.654879313767832, details={'was_impossible': False}),
#  Prediction(uid='807', iid='526', r_ui=5.0, est=4.325901376248805, details={'was_impossible': False}),
#  Prediction(uid='708', iid='15', r_ui=3.0, est=3.6663223681086885, details={'was_impossible': False}),
#  Prediction(uid='845', iid='904', r_ui=3.0, est=3.3733192835746286, details={'was_impossible': False}),
#  Prediction(uid='658', iid='471', r_ui=4.0, est=3.7611843490139276, details={'was_impossible': False}),
#  Prediction(uid='328', iid='194', r_ui=3.0, est=3.863341591057152, details={'was_impossible': False}),
#  Prediction(uid='663', iid='473', r_ui=3.0, est=3.0105454498455213, details={'was_impossible': False}),
#  Prediction(uid='537', iid='523', r_ui=3.0, est=3.370552302402936, details={'was_impossible': False}),
#  Prediction(uid='323', iid='1012', r_ui=4.0, est=3.704916485032708, details={'was_impossible': False}),
#  Prediction(uid='92', iid='834', r_ui=1.0, est=2.237805815823333, details={'was_impossible': False}),
#  Prediction(uid='161', iid='582', r_ui=1.0, est=2.4898871716789195, details={'was_impossible': False}),
#  Prediction(uid='198', iid='568', r_ui=3.0, est=3.4689571152281498, details={'was_impossible': False}),
#  Prediction(uid='650', iid='429', r_ui=4.0, est=3.336043783257981, details={'was_impossible': False}),
#  Prediction(uid='776', iid='708', r_ui=5.0, est=3.601915515724579, details={'was_impossible': False}),
#  Prediction(uid='617', iid='320', r_ui=5.0, est=2.721038703094933, details={'was_impossible': False}),
#  Prediction(uid='843', iid='121', r_ui=3.0, est=2.5753313164233553, details={'was_impossible': False}),
#  Prediction(uid='196', iid='173', r_ui=2.0, est=4.084673110889232, details={'was_impossible': False}),
#  Prediction(uid='37', iid='273', r_ui=3.0, est=3.5299845918548813, details={'was_impossible': False}),
#  Prediction(uid='402', iid='410', r_ui=1.0, est=3.459265849704904, details={'was_impossible': False}),
#  Prediction(uid='487', iid='1', r_ui=5.0, est=3.951243254027602, details={'was_impossible': False}),
#  Prediction(uid='133', iid='750', r_ui=4.0, est=3.596195117655805, details={'was_impossible': False}),
#  Prediction(uid='123', iid='23', r_ui=4.0, est=4.353587205185451, details={'was_impossible': False}),
#  Prediction(uid='788', iid='1248', r_ui=3.0, est=2.8698193058885417, details={'was_impossible': False}),
#  Prediction(uid='606', iid='1280', r_ui=2.0, est=3.4893364665048905, details={'was_impossible': False}),
#  Prediction(uid='151', iid='181', r_ui=5.0, est=4.532168105156199, details={'was_impossible': False}),
#  Prediction(uid='305', iid='338', r_ui=3.0, est=2.5059345192408258, details={'was_impossible': False}),
#  Prediction(uid='889', iid='297', r_ui=3.0, est=3.990608448441204, details={'was_impossible': False}),
#  Prediction(uid='253', iid='294', r_ui=4.0, est=3.5846242737890646, details={'was_impossible': False}),
#  Prediction(uid='553', iid='191', r_ui=4.0, est=4.552170624904589, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1541', r_ui=4.0, est=3.442904330933967, details={'was_impossible': False}),
#  Prediction(uid='285', iid='150', r_ui=5.0, est=3.6315695150479748, details={'was_impossible': False}),
#  Prediction(uid='77', iid='268', r_ui=5.0, est=3.1470174523217933, details={'was_impossible': False}),
#  Prediction(uid='455', iid='1137', r_ui=3.0, est=3.6802642396284124, details={'was_impossible': False}),
#  Prediction(uid='483', iid='313', r_ui=2.0, est=3.5771360377932178, details={'was_impossible': False}),
#  Prediction(uid='84', iid='15', r_ui=4.0, est=4.06832154856186, details={'was_impossible': False}),
#  Prediction(uid='709', iid='739', r_ui=3.0, est=3.6205870664111375, details={'was_impossible': False}),
#  Prediction(uid='579', iid='7', r_ui=3.0, est=3.0775550393152877, details={'was_impossible': False}),
#  Prediction(uid='327', iid='709', r_ui=4.0, est=3.7141128395820155, details={'was_impossible': False}),
#  Prediction(uid='805', iid='405', r_ui=3.0, est=2.7991928098006555, details={'was_impossible': False}),
#  Prediction(uid='786', iid='86', r_ui=4.0, est=3.904815912221068, details={'was_impossible': False}),
#  Prediction(uid='334', iid='301', r_ui=2.0, est=3.1112397238626235, details={'was_impossible': False}),
#  Prediction(uid='388', iid='773', r_ui=3.0, est=3.5371414276437947, details={'was_impossible': False}),
#  Prediction(uid='222', iid='1419', r_ui=1.0, est=2.249925909306415, details={'was_impossible': False}),
#  Prediction(uid='151', iid='433', r_ui=3.0, est=3.834186769554692, details={'was_impossible': False}),
#  Prediction(uid='556', iid='187', r_ui=5.0, est=4.440654091145553, details={'was_impossible': False}),
#  Prediction(uid='850', iid='490', r_ui=5.0, est=4.532313064790387, details={'was_impossible': False}),
#  Prediction(uid='291', iid='41', r_ui=4.0, est=3.5730560786038983, details={'was_impossible': False}),
#  Prediction(uid='846', iid='739', r_ui=4.0, est=3.2702814240696116, details={'was_impossible': False}),
#  Prediction(uid='332', iid='97', r_ui=5.0, est=4.714450635794528, details={'was_impossible': False}),
#  Prediction(uid='388', iid='307', r_ui=4.0, est=4.136847164926972, details={'was_impossible': False}),
#  Prediction(uid='776', iid='134', r_ui=4.0, est=3.8317750928334364, details={'was_impossible': False}),
#  Prediction(uid='642', iid='955', r_ui=3.0, est=3.775110630763942, details={'was_impossible': False}),
#  Prediction(uid='622', iid='402', r_ui=3.0, est=3.158517143470337, details={'was_impossible': False}),
#  Prediction(uid='890', iid='436', r_ui=3.0, est=3.714981393394208, details={'was_impossible': False}),
#  Prediction(uid='269', iid='640', r_ui=5.0, est=3.3332079584781105, details={'was_impossible': False}),
#  Prediction(uid='6', iid='32', r_ui=4.0, est=3.673425541429327, details={'was_impossible': False}),
#  Prediction(uid='313', iid='155', r_ui=2.0, est=2.7372821624979107, details={'was_impossible': False}),
#  Prediction(uid='417', iid='452', r_ui=2.0, est=2.629511448012809, details={'was_impossible': False}),
#  Prediction(uid='685', iid='299', r_ui=2.0, est=2.1149153192242167, details={'was_impossible': False}),
#  Prediction(uid='469', iid='64', r_ui=5.0, est=4.937179732800751, details={'was_impossible': False}),
#  Prediction(uid='806', iid='455', r_ui=3.0, est=3.308284027104905, details={'was_impossible': False}),
#  Prediction(uid='370', iid='64', r_ui=4.0, est=4.367711436169634, details={'was_impossible': False}),
#  Prediction(uid='313', iid='582', r_ui=2.0, est=3.7371616537972567, details={'was_impossible': False}),
#  Prediction(uid='303', iid='873', r_ui=3.0, est=2.6481106693356473, details={'was_impossible': False}),
#  Prediction(uid='363', iid='39', r_ui=4.0, est=2.7513385198482534, details={'was_impossible': False}),
#  Prediction(uid='882', iid='756', r_ui=3.0, est=3.2367334459188495, details={'was_impossible': False}),
#  Prediction(uid='466', iid='909', r_ui=5.0, est=3.60140170206733, details={'was_impossible': False}),
#  Prediction(uid='59', iid='25', r_ui=4.0, est=4.369235929813357, details={'was_impossible': False}),
#  Prediction(uid='186', iid='588', r_ui=4.0, est=3.8133356760073265, details={'was_impossible': False}),
#  Prediction(uid='735', iid='288', r_ui=4.0, est=2.9228586770037026, details={'was_impossible': False}),
#  Prediction(uid='52', iid='288', r_ui=3.0, est=4.026096964897181, details={'was_impossible': False}),
#  Prediction(uid='624', iid='255', r_ui=3.0, est=3.3617123550204595, details={'was_impossible': False}),
#  Prediction(uid='868', iid='378', r_ui=2.0, est=2.8667710198526066, details={'was_impossible': False}),
#  Prediction(uid='847', iid='367', r_ui=3.0, est=3.136508672590948, details={'was_impossible': False}),
#  Prediction(uid='675', iid='347', r_ui=4.0, est=3.413317432290794, details={'was_impossible': False}),
#  Prediction(uid='210', iid='97', r_ui=5.0, est=4.2447568813857455, details={'was_impossible': False}),
#  Prediction(uid='929', iid='654', r_ui=3.0, est=3.6948633326443563, details={'was_impossible': False}),
#  Prediction(uid='631', iid='307', r_ui=4.0, est=3.372992822991048, details={'was_impossible': False}),
#  Prediction(uid='72', iid='382', r_ui=4.0, est=3.5814949973824257, details={'was_impossible': False}),
#  Prediction(uid='276', iid='77', r_ui=3.0, est=3.6078211061014653, details={'was_impossible': False}),
#  Prediction(uid='459', iid='286', r_ui=4.0, est=3.892069880452808, details={'was_impossible': False}),
#  Prediction(uid='727', iid='421', r_ui=5.0, est=3.026769573350352, details={'was_impossible': False}),
#  Prediction(uid='75', iid='137', r_ui=4.0, est=3.693519317664769, details={'was_impossible': False}),
#  Prediction(uid='486', iid='327', r_ui=3.0, est=3.317459876267487, details={'was_impossible': False}),
#  Prediction(uid='882', iid='432', r_ui=5.0, est=4.06862590337067, details={'was_impossible': False}),
#  Prediction(uid='919', iid='1284', r_ui=3.0, est=3.073767350781075, details={'was_impossible': False}),
#  Prediction(uid='149', iid='310', r_ui=2.0, est=2.8571971276929404, details={'was_impossible': False}),
#  Prediction(uid='5', iid='454', r_ui=1.0, est=2.7734544427850105, details={'was_impossible': False}),
#  Prediction(uid='548', iid='466', r_ui=5.0, est=4.0112450936537405, details={'was_impossible': False}),
#  Prediction(uid='546', iid='977', r_ui=5.0, est=3.3306761151595516, details={'was_impossible': False}),
#  Prediction(uid='87', iid='196', r_ui=5.0, est=4.244535334407126, details={'was_impossible': False}),
#  Prediction(uid='847', iid='1', r_ui=3.0, est=3.067980348314227, details={'was_impossible': False}),
#  Prediction(uid='579', iid='88', r_ui=4.0, est=3.1614026179902868, details={'was_impossible': False}),
#  Prediction(uid='345', iid='956', r_ui=4.0, est=3.884832883376755, details={'was_impossible': False}),
#  Prediction(uid='327', iid='715', r_ui=4.0, est=2.9653181232249013, details={'was_impossible': False}),
#  Prediction(uid='234', iid='1221', r_ui=4.0, est=2.899255468210551, details={'was_impossible': False}),
#  Prediction(uid='854', iid='479', r_ui=4.0, est=3.9952018940406018, details={'was_impossible': False}),
#  Prediction(uid='807', iid='566', r_ui=4.0, est=4.171754338479449, details={'was_impossible': False}),
#  Prediction(uid='396', iid='472', r_ui=5.0, est=3.4242883301403917, details={'was_impossible': False}),
#  Prediction(uid='719', iid='79', r_ui=4.0, est=3.3945386877940114, details={'was_impossible': False}),
#  Prediction(uid='312', iid='740', r_ui=4.0, est=4.015201966891535, details={'was_impossible': False}),
#  Prediction(uid='436', iid='785', r_ui=2.0, est=3.5008423196345917, details={'was_impossible': False}),
#  Prediction(uid='592', iid='881', r_ui=1.0, est=3.1452391251872043, details={'was_impossible': False}),
#  Prediction(uid='624', iid='886', r_ui=4.0, est=2.9488366969563335, details={'was_impossible': False}),
#  Prediction(uid='916', iid='2', r_ui=3.0, est=2.652152603241914, details={'was_impossible': False}),
#  Prediction(uid='95', iid='71', r_ui=5.0, est=3.8639557449474995, details={'was_impossible': False}),
#  Prediction(uid='262', iid='567', r_ui=1.0, est=2.6249377511650773, details={'was_impossible': False}),
#  Prediction(uid='606', iid='168', r_ui=5.0, est=4.2399702306172955, details={'was_impossible': False}),
#  Prediction(uid='398', iid='235', r_ui=2.0, est=2.4572055603432927, details={'was_impossible': False}),
#  Prediction(uid='321', iid='215', r_ui=3.0, est=3.3656966531205907, details={'was_impossible': False}),
#  Prediction(uid='686', iid='2', r_ui=3.0, est=3.9084522477354704, details={'was_impossible': False}),
#  Prediction(uid='619', iid='879', r_ui=4.0, est=3.50479749206058, details={'was_impossible': False}),
#  Prediction(uid='932', iid='659', r_ui=5.0, est=4.197570888747439, details={'was_impossible': False}),
#  Prediction(uid='308', iid='275', r_ui=4.0, est=3.9229246743571977, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1241', r_ui=2.0, est=2.738923250358685, details={'was_impossible': False}),
#  Prediction(uid='351', iid='751', r_ui=4.0, est=4.4081176856222735, details={'was_impossible': False}),
#  Prediction(uid='269', iid='661', r_ui=4.0, est=3.937883694108683, details={'was_impossible': False}),
#  Prediction(uid='93', iid='118', r_ui=3.0, est=3.0390174025798338, details={'was_impossible': False}),
#  Prediction(uid='425', iid='823', r_ui=3.0, est=2.389983887005012, details={'was_impossible': False}),
#  Prediction(uid='524', iid='310', r_ui=4.0, est=3.854275379317344, details={'was_impossible': False}),
#  Prediction(uid='618', iid='371', r_ui=3.0, est=2.6177321485487988, details={'was_impossible': False}),
#  Prediction(uid='268', iid='182', r_ui=4.0, est=3.967672508650841, details={'was_impossible': False}),
#  Prediction(uid='324', iid='538', r_ui=4.0, est=4.645660249128016, details={'was_impossible': False}),
#  Prediction(uid='899', iid='740', r_ui=5.0, est=3.719430176256544, details={'was_impossible': False}),
#  Prediction(uid='87', iid='80', r_ui=4.0, est=3.213082709758991, details={'was_impossible': False}),
#  Prediction(uid='825', iid='925', r_ui=4.0, est=3.870685944078817, details={'was_impossible': False}),
#  Prediction(uid='378', iid='272', r_ui=4.0, est=4.00755647473853, details={'was_impossible': False}),
#  Prediction(uid='774', iid='135', r_ui=3.0, est=2.8362704887838146, details={'was_impossible': False}),
#  Prediction(uid='930', iid='238', r_ui=4.0, est=3.321647722727165, details={'was_impossible': False}),
#  Prediction(uid='704', iid='604', r_ui=5.0, est=3.9927664166931134, details={'was_impossible': False}),
#  Prediction(uid='854', iid='509', r_ui=4.0, est=3.5204297039621606, details={'was_impossible': False}),
#  Prediction(uid='704', iid='185', r_ui=4.0, est=3.966914858876925, details={'was_impossible': False}),
#  Prediction(uid='497', iid='1407', r_ui=3.0, est=2.899250198927748, details={'was_impossible': False}),
#  Prediction(uid='429', iid='166', r_ui=5.0, est=4.00477618400649, details={'was_impossible': False}),
#  Prediction(uid='255', iid='597', r_ui=4.0, est=2.3869289607814492, details={'was_impossible': False}),
#  Prediction(uid='406', iid='136', r_ui=4.0, est=3.783320498857608, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# ## Evaluation

# %%
from surprise import accuracy

accuracy.rmse(predictions=predictions)
# Out:
# RMSE: 0.9380
# 0.9380006431882001

# %%
accuracy.mae(predictions=predictions)
# Out:
# MAE:  0.7397
# 0.7396981029970237

# %% [markdown]
# # Cross validation

# %%
from surprise.model_selection import cross_validate

cross_validate(model, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9314  0.9307  0.9312  0.9438  0.9345  0.9343  0.0049
# MAE (testset)     0.7326  0.7327  0.7363  0.7426  0.7357  0.7360  0.0036
# Fit time          3.72    3.66    3.64    3.85    3.88    3.75    0.10
# Test time         0.10    0.19    0.10    0.10    0.19    0.14    0.04
# {'test_rmse': array([0.93137282, 0.93073342, 0.93119095, 0.94378029, 0.9345494 ]),
#  'test_mae': array([0.73262706, 0.73267075, 0.73625911, 0.74260416, 0.73574617]),
#  'fit_time': (3.715752124786377,
#   3.6570870876312256,
#   3.6384329795837402,
#   3.845144033432007,
#   3.878741979598999),
#  'test_time': (0.09677886962890625,
#   0.19050812721252441,
#   0.10015392303466797,
#   0.10469675064086914,
#   0.1918962001800537)}
